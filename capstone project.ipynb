# %%
## API key  AIzaSyDC7otU4u6MNGZgqmEzUxoAz_8CpWWLyRs

# %%
from googleapiclient.discovery import build
import pymongo
import pandas as pd
import streamlit as st

# %%
## API Connect
def api_connect():
    api_id="AIzaSyDC7otU4u6MNGZgqmEzUxoAz_8CpWWLyRs"
    api_service_name="youtube"
    api_version="v3"
    youtube=build(api_service_name,api_version,developerKey=api_id)
    return youtube
youtube=api_connect()

# %%
## channel information
request=youtube.channels().list(
                part="snippet,ContentDetails,statistics",
                id="UCmrsodcsfoZyFwW_f-ZtvfQ"
)
response=request.execute()
for i in response["items"]:
    data=dict(channel_name=i["snippet"]["title"],
             channel_id=i['id'],
             sub_count=i["statistics"]["subscriberCount"],
              v_count=i["statistics"]["videoCount"])
    print(data)
# Out:
# {'channel_name': 'manichow', 'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ', 'sub_count': '240000', 'v_count': '31'}

# %%
def get_channel_info(channel_id):
    request=youtube.channels().list(
                    part="snippet,ContentDetails,statistics",
                    id=channel_id
    )
    response=request.execute()
    for i in response["items"]:
        data=dict(channel_name=i["snippet"]["title"],
                 channel_id=i['id'],
                 subscribers_count=i["statistics"]["subscriberCount"],
                 videos_count=i["statistics"]["videoCount"],
                 views=i["statistics"]["viewCount"],
                 channel_Description=i["snippet"]["description"],
                 playlist_id=i["contentDetails"]["relatedPlaylists"]["uploads"])
    return data

# %%
channel_details=get_channel_info("UCmrsodcsfoZyFwW_f-ZtvfQ")
channel_details
# Out:
# {'channel_name': 'manichow',
#  'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#  'subscribers_count': '240000',
#  'videos_count': '31',
#  'views': '8506202',
#  'channel_Description': "she's a 10 but embarrasses herself on the internet",
#  'playlist_id': 'UUmrsodcsfoZyFwW_f-ZtvfQ'}

# %%
response["items"]
# Out:
# [{'kind': 'youtube#channel',
#   'etag': 'cuzDBO4MbqW5QTZ6HxyAFIcVYMY',
#   'id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'snippet': {'title': 'manichow',
#    'description': "she's a 10 but embarrasses herself on the internet",
#    'customUrl': '@manichoww',
#    'publishedAt': '2022-12-30T12:56:11.770086Z',
#    'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/XG_Ge3JtWJ5Odr-_o-VczIcTYZSToL7CqHWvuuHix3P9godQknaaXZXp2dZkBcPhvjq5K-sF=s88-c-k-c0x00ffffff-no-rj',
#      'width': 88,
#      'height': 88},
#     'medium': {'url': 'https://yt3.ggpht.com/XG_Ge3JtWJ5Odr-_o-VczIcTYZSToL7CqHWvuuHix3P9godQknaaXZXp2dZkBcPhvjq5K-sF=s240-c-k-c0x00ffffff-no-rj',
#      'width': 240,
#      'height': 240},
#     'high': {'url': 'https://yt3.ggpht.com/XG_Ge3JtWJ5Odr-_o-VczIcTYZSToL7CqHWvuuHix3P9godQknaaXZXp2dZkBcPhvjq5K-sF=s800-c-k-c0x00ffffff-no-rj',
#      'width': 800,
#      'height': 800}},
#    'localized': {'title': 'manichow',
#     'description': "she's a 10 but embarrasses herself on the internet"}},
#   'contentDetails': {'relatedPlaylists': {'likes': '',
#     'uploads': 'UUmrsodcsfoZyFwW_f-ZtvfQ'}},
#   'statistics': {'viewCount': '8506202',
#    'subscriberCount': '240000',
#    'hiddenSubscriberCount': False,
#    'videoCount': '31'}}]

# %%
## getting videos id from playlist

# %%
video_id=youtube.channels().list(id="UCmrsodcsfoZyFwW_f-ZtvfQ",
                                part="contentDetails").execute()
playlist_id=video_id["items"][0]["contentDetails"]["relatedPlaylists"]['uploads']
video_playlist_details=youtube.playlistItems().list(
                                                    part="snippet",
                                                    playlistId=playlist_id, maxResults=50).execute()

# %%
video_playlist_details['items'][0]['snippet']["resourceId"]['videoId']
# Out:
# 'SvKssslvta4'

# %%
def get_all_video_ids(channel_id):
    video_ids=[]
    video_id=youtube.channels().list(id=channel_id,
                                    part="contentDetails").execute()
    playlist_id=video_id["items"][0]["contentDetails"]["relatedPlaylists"]['uploads']
    next_page_token=None
    while True:
        video_playlist_details=youtube.playlistItems().list(
                                                            part="snippet",
                                                            playlistId=playlist_id, 
                                                            maxResults=50,
                                                            pageToken=next_page_token).execute()
        for i in range (len(video_playlist_details['items'])):
            video_ids.append(video_playlist_details['items'][i]['snippet']["resourceId"]['videoId'])
        next_page_token=video_playlist_details.get('nextPageToken')
        if next_page_token is None:
            break  
    return video_ids

# %%
## to get a video id of particular channel
video_Ids_channel=get_all_video_ids("UCmrsodcsfoZyFwW_f-ZtvfQ")

# %%
len(video_Ids_channel)
video_Ids_channel
# Out:
# ['SvKssslvta4',
#  'T8s3QOpCX9A',
#  'Hf1KFD98nx0',
#  'NEqmKa-e9vE',
#  'L7cAq6KyR18',
#  'YHnWK0gPNpM',
#  '_XxWxBaXCnY',
#  'cv0ZHaplbIY',
#  'b50LfkF5wio',
#  'UO0RvM6K0Oc',
#  'ga9qgTKSN90',
#  '7JVFmpJ3v48',
#  '6gKGQlJ0cOA',
#  'VAz1cqW9RjM',
#  '4rvoO920Awo',
#  'kwPdbzIwdgY',
#  'CAWuFGmuXlE',
#  'MlW8d0C9220',
#  'Waf9QE0zeFc',
#  'J1kKo_we7pA',
#  '6MFWw-01hHQ',
#  'yP0KKqnzHYw',
#  'iVwtFofco0Y',
#  'zzbi1eLLIpQ',
#  'SkqWj1FW2bE',
#  'RaksVyGbM4k',
#  'dlvdW9iU5nk',
#  '3TtNdO4A_2g',
#  'WnkQnKuQiH8',
#  'pPwnwpoWp3I',
#  'HiI-bSZzGDM']

# %%
for video_id in video_Ids_channel:
    request=youtube.videos().list(
        part="snippet,ContentDetails,statistics",
        id=video_id
    )
    response=request.execute()
    for item in response['items']:
        video_data=dict(channel_name=item['snippet']['channelTitle'],
                       channel_id=item['snippet']['channelId'],
                       video_id=item['id'],
                       video_tittle=item['snippet']['title'],
                       v_thumbnail=item['snippet']['thumbnails'],
                       v_description=item['snippet']['description'],
                       v_date_of_publish=item['snippet']['publishedAt'],
                       video_duration=item['contentDetails']['duration'],
                        views_count=item['statistics']['viewCount'],
                        comment_count=item['statistics']['commentCount'],
                        like_count=item['statistics']['likeCount'],
                        fav_count=item['statistics']['favoriteCount'],
                        video_Definition=item['contentDetails']['definition'],
                        Caption_status=item['contentDetails']['caption']
                       )

# %%
video_data=[]
for video_id in video_Ids_channel:
    request=youtube.videos().list(
        part="snippet,ContentDetails,statistics",
        id=video_id
    )
    response=request.execute()
    for item in response['items']:
        video_info=dict(channel_name=item['snippet']['channelTitle'],
                       channel_id=item['snippet']['channelId'],
                       video_id=item['id'],
                       video_tittle=item['snippet']['title'],
                       v_thumbnail=item['snippet']['thumbnails'],
                       v_description=item['snippet']['description'],
                       video_tags=item.get('tags'),
                       v_date_of_publish=item['snippet']['publishedAt'],
                       video_duration=item['contentDetails']['duration'],
                        views_count=item['statistics']['viewCount'],
                        comment_count=item.get('commentCount'),
                        like_count=item['statistics']['likeCount'],
                        fav_count=item['statistics']['favoriteCount'],
                        video_Definition=item['contentDetails']['definition'],
                        Caption_status=item['contentDetails']['caption']
                       )
        video_data.append(video_info)
##if any items not available use ##get function eg video_tags=item.get('tags')

# %%
video_data
# Out:
# [{'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'SvKssslvta4',
#   'video_tittle': 'sillarayai sedhara vitten 🛵💥',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/SvKssslvta4/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/SvKssslvta4/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/SvKssslvta4/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/SvKssslvta4/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/SvKssslvta4/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': "pls don't bully me with more mutti jokes :(",
#   'video_tags': None,
#   'v_date_of_publish': '2024-04-22T14:08:36Z',
#   'video_duration': 'PT13M39S',
#   'views_count': '210778',
#   'comment_count': None,
#   'like_count': '16186',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'T8s3QOpCX9A',
#   'video_tittle': "✨influencer's era✨",
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/T8s3QOpCX9A/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/T8s3QOpCX9A/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/T8s3QOpCX9A/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/T8s3QOpCX9A/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/T8s3QOpCX9A/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'ennayum ipl commentary koopdunga 😋',
#   'video_tags': None,
#   'v_date_of_publish': '2024-04-16T13:31:06Z',
#   'video_duration': 'PT16M4S',
#   'views_count': '425348',
#   'comment_count': None,
#   'like_count': '33818',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'Hf1KFD98nx0',
#   'video_tittle': 'who let them cook🥸?',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/Hf1KFD98nx0/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/Hf1KFD98nx0/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/Hf1KFD98nx0/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/Hf1KFD98nx0/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/Hf1KFD98nx0/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'social anxiety is scared of them 💀👍',
#   'video_tags': None,
#   'v_date_of_publish': '2024-03-06T14:00:10Z',
#   'video_duration': 'PT9M35S',
#   'views_count': '462089',
#   'comment_count': None,
#   'like_count': '26345',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'NEqmKa-e9vE',
#   'video_tittle': 'is it really yes all men?',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/NEqmKa-e9vE/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/NEqmKa-e9vE/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/NEqmKa-e9vE/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/NEqmKa-e9vE/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/NEqmKa-e9vE/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': "if I'm wrong anywhere in the video, please let me know in the comments. Post your views on this as well.",
#   'video_tags': None,
#   'v_date_of_publish': '2024-02-18T13:47:10Z',
#   'video_duration': 'PT18M24S',
#   'views_count': '374559',
#   'comment_count': None,
#   'like_count': '34653',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'L7cAq6KyR18',
#   'video_tittle': 'kutti manichow kadhaigal 2 🎀✨',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/L7cAq6KyR18/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/L7cAq6KyR18/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/L7cAq6KyR18/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/L7cAq6KyR18/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/L7cAq6KyR18/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'tap la sudu thanni vardhu😥😲💥‼️\n\n\n\n\nInstagram : https://www.instagram.com/manichoww/',
#   'video_tags': None,
#   'v_date_of_publish': '2024-02-04T14:00:19Z',
#   'video_duration': 'PT11M29S',
#   'views_count': '154892',
#   'comment_count': None,
#   'like_count': '11483',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'YHnWK0gPNpM',
#   'video_tittle': 'na ambani aaga poren💸‼️',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/YHnWK0gPNpM/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/YHnWK0gPNpM/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/YHnWK0gPNpM/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/YHnWK0gPNpM/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/YHnWK0gPNpM/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'janavary 31st vandha dhananga new year kondaada mudiyum👺‼️\n\n\n\ninstagram : https://www.instagram.com/manichoww',
#   'video_tags': None,
#   'v_date_of_publish': '2024-01-15T14:00:20Z',
#   'video_duration': 'PT14M6S',
#   'views_count': '246612',
#   'comment_count': None,
#   'like_count': '16894',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': '_XxWxBaXCnY',
#   'video_tittle': 'one year of manichow 🎈',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/_XxWxBaXCnY/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/_XxWxBaXCnY/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/_XxWxBaXCnY/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/_XxWxBaXCnY/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/_XxWxBaXCnY/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'welcome to my youtube channel guys! hope you like my videos 😉🥰\nlike, share and subscribe for more content 😄🤪💥',
#   'video_tags': None,
#   'v_date_of_publish': '2023-12-31T13:48:03Z',
#   'video_duration': 'PT9M42S',
#   'views_count': '282863',
#   'comment_count': None,
#   'like_count': '23588',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'cv0ZHaplbIY',
#   'video_tittle': 'i make you a sandwich and rant about hate 🤓',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/cv0ZHaplbIY/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/cv0ZHaplbIY/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/cv0ZHaplbIY/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/cv0ZHaplbIY/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/cv0ZHaplbIY/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'thakida thakida thakida thakida thaaa 🕺💥\n\nmy instagram: https://www.instagram.com/manichoww/',
#   'video_tags': None,
#   'v_date_of_publish': '2023-12-25T14:00:30Z',
#   'video_duration': 'PT14M21S',
#   'views_count': '377171',
#   'comment_count': None,
#   'like_count': '30584',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'b50LfkF5wio',
#   'video_tittle': 'back to the kitchen ⏪',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/b50LfkF5wio/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/b50LfkF5wio/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/b50LfkF5wio/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/b50LfkF5wio/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/b50LfkF5wio/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'yaar ennai samaika vittadhu??!',
#   'video_tags': None,
#   'v_date_of_publish': '2023-12-19T13:30:16Z',
#   'video_duration': 'PT15M34S',
#   'views_count': '637836',
#   'comment_count': None,
#   'like_count': '42534',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'UO0RvM6K0Oc',
#   'video_tittle': 'i speak in english, i slap myself 👍',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/UO0RvM6K0Oc/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/UO0RvM6K0Oc/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/UO0RvM6K0Oc/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/UO0RvM6K0Oc/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/UO0RvM6K0Oc/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': '*நான் ஆங்கிலத்தில் பேசினால், என்னை நான் அறைந்து விடுவேன் 👍',
#   'video_tags': None,
#   'v_date_of_publish': '2023-11-23T14:00:30Z',
#   'video_duration': 'PT9M1S',
#   'views_count': '1569307',
#   'comment_count': None,
#   'like_count': '99389',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'ga9qgTKSN90',
#   'video_tittle': 'indian rizzlords 🗿',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/ga9qgTKSN90/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/ga9qgTKSN90/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/ga9qgTKSN90/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/ga9qgTKSN90/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/ga9qgTKSN90/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': "i wish to be colonised once again, this ain't it 🙏",
#   'video_tags': None,
#   'v_date_of_publish': '2023-11-07T14:11:27Z',
#   'video_duration': 'PT15M55S',
#   'views_count': '462049',
#   'comment_count': None,
#   'like_count': '24646',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': '7JVFmpJ3v48',
#   'video_tittle': 'lets talk about concerts in chennai 🕺',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/7JVFmpJ3v48/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/7JVFmpJ3v48/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/7JVFmpJ3v48/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/7JVFmpJ3v48/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/7JVFmpJ3v48/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'thilele podu thileley 😙🕺',
#   'video_tags': None,
#   'v_date_of_publish': '2023-10-05T14:00:09Z',
#   'video_duration': 'PT13M16S',
#   'views_count': '156234',
#   'comment_count': None,
#   'like_count': '8652',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': '6gKGQlJ0cOA',
#   'video_tittle': 'manichow watches another button video👍',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/6gKGQlJ0cOA/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/6gKGQlJ0cOA/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/6gKGQlJ0cOA/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/6gKGQlJ0cOA/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/6gKGQlJ0cOA/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'screw the button, come to me for matchmaking / couples therapy ✅',
#   'video_tags': None,
#   'v_date_of_publish': '2023-09-22T14:00:28Z',
#   'video_duration': 'PT12M54S',
#   'views_count': '158140',
#   'comment_count': None,
#   'like_count': '10293',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'VAz1cqW9RjM',
#   'video_tittle': 'the pressure to always stay on trend 👩\u200d🦯',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/VAz1cqW9RjM/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/VAz1cqW9RjM/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/VAz1cqW9RjM/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/VAz1cqW9RjM/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/VAz1cqW9RjM/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'this video may or may not be a defence mechanism against people who call me cringe 😙\nand yes, cringe panunga vaazhka nalla irukum 🥰',
#   'video_tags': None,
#   'v_date_of_publish': '2023-08-23T14:15:26Z',
#   'video_duration': 'PT8M45S',
#   'views_count': '124272',
#   'comment_count': None,
#   'like_count': '8519',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': '4rvoO920Awo',
#   'video_tittle': 'reacting to youtube comments cause im famous now 😙💅',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/4rvoO920Awo/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/4rvoO920Awo/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/4rvoO920Awo/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/4rvoO920Awo/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/4rvoO920Awo/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'if your comment\'s gonna contain "akka" in it, keep it to yourself.\n\n\n\nchumma sonnen go ahead and post it, i can use the engagement 😙👍',
#   'video_tags': None,
#   'v_date_of_publish': '2023-08-05T15:16:12Z',
#   'video_duration': 'PT10M19S',
#   'views_count': '240339',
#   'comment_count': None,
#   'like_count': '16028',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'kwPdbzIwdgY',
#   'video_tittle': 'reels paaklama champions 😋',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/kwPdbzIwdgY/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/kwPdbzIwdgY/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/kwPdbzIwdgY/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/kwPdbzIwdgY/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/kwPdbzIwdgY/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'indha video ah like panikonga apdiye subscribe um sethu panikonga champions 🥰',
#   'video_tags': None,
#   'v_date_of_publish': '2023-07-18T14:30:08Z',
#   'video_duration': 'PT8M54S',
#   'views_count': '918022',
#   'comment_count': None,
#   'like_count': '45571',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'CAWuFGmuXlE',
#   'video_tittle': 'project makeover ads are getting out of hand !',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/CAWuFGmuXlE/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/CAWuFGmuXlE/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/CAWuFGmuXlE/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/CAWuFGmuXlE/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/CAWuFGmuXlE/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'who let them cook?',
#   'video_tags': None,
#   'v_date_of_publish': '2023-06-30T13:56:10Z',
#   'video_duration': 'PT10M21S',
#   'views_count': '95872',
#   'comment_count': None,
#   'like_count': '4944',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'MlW8d0C9220',
#   'video_tittle': 'reviewing IIFA awards 2023 outfits 😙🎀',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/MlW8d0C9220/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/MlW8d0C9220/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/MlW8d0C9220/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/MlW8d0C9220/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/MlW8d0C9220/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': '"it\'s not that bad, it\'s good"',
#   'video_tags': None,
#   'v_date_of_publish': '2023-06-17T14:01:40Z',
#   'video_duration': 'PT10M40S',
#   'views_count': '135404',
#   'comment_count': None,
#   'like_count': '6522',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'Waf9QE0zeFc',
#   'video_tittle': 'deranged makeover + modern love chennai review 💄✨',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/Waf9QE0zeFc/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/Waf9QE0zeFc/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/Waf9QE0zeFc/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/Waf9QE0zeFc/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/Waf9QE0zeFc/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': '"vazhkaila minor inconvenience iruklam, vazhkaye minor inconvenience ah iruka kudadhu" - priviledged 19 year old on youtube (me)\n.\n.\nfilm review is just for like 3 mins towards the end , clickbait kaga title la potruken 🤝',
#   'video_tags': None,
#   'v_date_of_publish': '2023-06-01T15:34:48Z',
#   'video_duration': 'PT11M48S',
#   'views_count': '96186',
#   'comment_count': None,
#   'like_count': '4211',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'J1kKo_we7pA',
#   'video_tittle': 'kutti manichow kadhaigal :3',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/J1kKo_we7pA/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/J1kKo_we7pA/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/J1kKo_we7pA/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/J1kKo_we7pA/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/J1kKo_we7pA/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'ozhungu mariyadhaya childhood memory ah comment pannu, illana attack dhan 😡🔪',
#   'video_tags': None,
#   'v_date_of_publish': '2023-05-19T14:21:23Z',
#   'video_duration': 'PT9M53S',
#   'views_count': '111924',
#   'comment_count': None,
#   'like_count': '5976',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': '6MFWw-01hHQ',
#   'video_tittle': 'pov : your highschool bully just became a finance advisor',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/6MFWw-01hHQ/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/6MFWw-01hHQ/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/6MFWw-01hHQ/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/6MFWw-01hHQ/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/6MFWw-01hHQ/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': '"nee saavum podhukuda edhuvume anubavikaama dummy ah dhan saava"\n- goddamn_queen_ , 2023 🛐',
#   'video_tags': None,
#   'v_date_of_publish': '2023-05-03T14:30:13Z',
#   'video_duration': 'PT11M48S',
#   'views_count': '328295',
#   'comment_count': None,
#   'like_count': '14131',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'yP0KKqnzHYw',
#   'video_tittle': "spoof news (it's my college project)",
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/yP0KKqnzHYw/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/yP0KKqnzHYw/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/yP0KKqnzHYw/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/yP0KKqnzHYw/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/yP0KKqnzHYw/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'call me ms. sustainable the way i reuse every piece of content i ever make.',
#   'video_tags': None,
#   'v_date_of_publish': '2023-04-19T14:06:57Z',
#   'video_duration': 'PT5M14S',
#   'views_count': '45428',
#   'comment_count': None,
#   'like_count': '2622',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'iVwtFofco0Y',
#   'video_tittle': 'watching ridiculous game ads + playing one of them',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/iVwtFofco0Y/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/iVwtFofco0Y/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/iVwtFofco0Y/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/iVwtFofco0Y/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/iVwtFofco0Y/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'I thought nothing could top the absurdity of my fever dreams, I was wrong.',
#   'video_tags': None,
#   'v_date_of_publish': '2023-04-13T13:39:15Z',
#   'video_duration': 'PT15M53S',
#   'views_count': '124940',
#   'comment_count': None,
#   'like_count': '7404',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'zzbi1eLLIpQ',
#   'video_tittle': 'is he the certified lover boi of kerala?',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/zzbi1eLLIpQ/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/zzbi1eLLIpQ/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/zzbi1eLLIpQ/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/zzbi1eLLIpQ/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/zzbi1eLLIpQ/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'me when the women \nhttps://www.instagram.com/reel/CmEWlhtJbDn/?utm_source=ig_web_copy_link😙❤️',
#   'video_tags': None,
#   'v_date_of_publish': '2023-03-17T14:30:02Z',
#   'video_duration': 'PT13M30S',
#   'views_count': '204941',
#   'comment_count': None,
#   'like_count': '10426',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'SkqWj1FW2bE',
#   'video_tittle': 'why do movies glorify tf out of college life?',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/SkqWj1FW2bE/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/SkqWj1FW2bE/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/SkqWj1FW2bE/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/SkqWj1FW2bE/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/SkqWj1FW2bE/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': "this is'nt very hip college student of me i apologise 😔 🙏",
#   'video_tags': None,
#   'v_date_of_publish': '2023-02-26T13:30:09Z',
#   'video_duration': 'PT11M7S',
#   'views_count': '136389',
#   'comment_count': None,
#   'like_count': '6728',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'RaksVyGbM4k',
#   'video_tittle': 'i found the most ruthless show ever!? (i like watching people in pain)',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/RaksVyGbM4k/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/RaksVyGbM4k/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/RaksVyGbM4k/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/RaksVyGbM4k/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/RaksVyGbM4k/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'we can be friends if you want 🤝',
#   'video_tags': None,
#   'v_date_of_publish': '2023-02-16T13:37:30Z',
#   'video_duration': 'PT15M43S',
#   'views_count': '42430',
#   'comment_count': None,
#   'like_count': '2489',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'dlvdW9iU5nk',
#   'video_tittle': 'certified lover boi of tamilnadu',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/dlvdW9iU5nk/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/dlvdW9iU5nk/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/dlvdW9iU5nk/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/dlvdW9iU5nk/sddefault.jpg',
#     'width': 640,
#     'height': 480}},
#   'v_description': 'description? this is how my friend described him : "POV softcore por- pork✅ panuvaney reels la"',
#   'video_tags': None,
#   'v_date_of_publish': '2023-02-01T15:37:40Z',
#   'video_duration': 'PT11M59S',
#   'views_count': '210424',
#   'comment_count': None,
#   'like_count': '9846',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': '3TtNdO4A_2g',
#   'video_tittle': 'why do we have zero road sense?',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/3TtNdO4A_2g/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/3TtNdO4A_2g/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/3TtNdO4A_2g/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/3TtNdO4A_2g/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/3TtNdO4A_2g/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'Indian drivers took "irupadhu oru lifeu adichuka cheers" in the wrong sense.',
#   'video_tags': None,
#   'v_date_of_publish': '2023-01-23T15:36:26Z',
#   'video_duration': 'PT8M2S',
#   'views_count': '29020',
#   'comment_count': None,
#   'like_count': '1791',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'WnkQnKuQiH8',
#   'video_tittle': 'The Best Motivational Speaker on Instagram',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/WnkQnKuQiH8/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/WnkQnKuQiH8/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/WnkQnKuQiH8/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/WnkQnKuQiH8/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/WnkQnKuQiH8/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': "I'm gonna motivate you so bad, you'll finally get a life.",
#   'video_tags': None,
#   'v_date_of_publish': '2023-01-14T13:28:20Z',
#   'video_duration': 'PT5M53S',
#   'views_count': '44869',
#   'comment_count': None,
#   'like_count': '2059',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'pPwnwpoWp3I',
#   'video_tittle': 'new year, new hair, possibly new me?',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/pPwnwpoWp3I/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/pPwnwpoWp3I/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/pPwnwpoWp3I/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/pPwnwpoWp3I/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/pPwnwpoWp3I/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'she found the words "rather" and "enna porutha varikum" and never shut up since.\n.\n\n\n\n\n\n\n\n\n.\nsincere apologies for the poorly edited thumbnail 🙏',
#   'video_tags': None,
#   'v_date_of_publish': '2023-01-06T14:50:07Z',
#   'video_duration': 'PT11M20S',
#   'views_count': '27736',
#   'comment_count': None,
#   'like_count': '1496',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'HiI-bSZzGDM',
#   'video_tittle': 'scrolling mindlessly',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/HiI-bSZzGDM/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/HiI-bSZzGDM/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/HiI-bSZzGDM/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/HiI-bSZzGDM/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/HiI-bSZzGDM/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'embarrassing myself to create the illusion of productivity 🗿',
#   'video_tags': None,
#   'v_date_of_publish': '2022-12-30T13:33:23Z',
#   'video_duration': 'PT7M4S',
#   'views_count': '87726',
#   'comment_count': None,
#   'like_count': '5409',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'}]

# %%
len(video_data)
# Out:
# 31

# %%
for i in video_data:
    print(i)
# Out:
# {'channel_name': 'manichow', 'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ', 'video_id': 'SvKssslvta4', 'video_tittle': 'sillarayai sedhara vitten 🛵💥', 'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/SvKssslvta4/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/SvKssslvta4/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/SvKssslvta4/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/SvKssslvta4/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/SvKssslvta4/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'v_description': "pls don't bully me with more mutti jokes :(", 'video_tags': None, 'v_date_of_publish': '2024-04-22T14:08:36Z', 'video_duration': 'PT13M39S', 'views_count': '210778', 'comment_count': None, 'like_count': '16186', 'fav_count': '0', 'video_Definition': 'hd', 'Caption_status': 'false'}
# {'channel_name': 'manichow', 'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ', 'video_id': 'T8s3QOpCX9A', 'video_tittle': "✨influencer's era✨", 'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/T8s3QOpCX9A/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/T8s3QOpCX9A/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/T8s3QOpCX9A/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/T8s3QOpCX9A/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/T8s3QOpCX9A/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'v_description': 'ennayum ipl commentary koopdunga 😋', 'video_tags': None, 'v_date_of_publish': '2024-04-16T13:31:06Z', 'video_duration': 'PT16M4S', 'views_count': '425348', 'comment_count': None, 'like_count': '33818', 'fav_count': '0', 'video_Definition': 'hd', 'Caption_status': 'false'}
# {'channel_name': 'manichow', 'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ', 'video_id': 'Hf1KFD98nx0', 'video_tittle': 'who let them cook🥸?', 'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/Hf1KFD98nx0/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/Hf1KFD98nx0/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/Hf1KFD98nx0/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/Hf1KFD98nx0/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/Hf1KFD98nx0/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'v_description': 'social anxiety is scared of them 💀👍', 'video_tags': None, 'v_date_of_publish': '2024-03-06T14:00:10Z', 'video_duration': 'PT9M35S', 'views_count': '462089', 'comment_count': None, 'like_count': '26345', 'fav_count': '0', 'video_Definition': 'hd', 'Caption_status': 'false'}
# {'channel_name': 'manichow', 'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ', 'video_id': 'NEqmKa-e9vE', 'video_tittle': 'is it really yes all men?', 'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/NEqmKa-e9vE/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/NEqmKa-e9vE/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/NEqmKa-e9vE/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/NEqmKa-e9vE/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/NEqmKa-e9vE/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'v_description': "if I'm wrong anywhere in the video, please let me know in the comments. Post your views on this as well.", 'video_tags': None, 'v_date_of_publish': '2024-02-18T13:47:10Z', 'video_duration': 'PT18M24S', 'views_count': '374559', 'comment_count': None, 'like_count': '34653', 'fav_count': '0', 'video_Definition': 'hd', 'Caption_status': 'false'}
# {'channel_name': 'manichow', 'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ', 'video_id': 'L7cAq6KyR18', 'video_tittle': 'kutti manichow kadhaigal 2 🎀✨', 'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/L7cAq6KyR18/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/L7cAq6KyR18/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/L7cAq6KyR18/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/L7cAq6KyR18/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/L7cAq6KyR18/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'v_description': 'tap la sudu thanni vardhu😥😲💥‼️\n\n\n\n\nInstagram : https://www.instagram.com/manichoww/', 'video_tags': None, 'v_date_of_publish': '2024-02-04T14:00:19Z', 'video_duration': 'PT11M29S', 'views_count': '154892', 'comment_count': None, 'like_count': '11483', 'fav_count': '0', 'video_Definition': 'hd', 'Caption_status': 'false'}
# {'channel_name': 'manichow', 'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ', 'video_id': 'YHnWK0gPNpM', 'video_tittle': 'na ambani aaga poren💸‼️', 'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/YHnWK0gPNpM/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/YHnWK0gPNpM/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/YHnWK0gPNpM/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/YHnWK0gPNpM/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/YHnWK0gPNpM/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'v_description': 'janavary 31st vandha dhananga new year kondaada mudiyum👺‼️\n\n\n\ninstagram : https://www.instagram.com/manichoww', 'video_tags': None, 'v_date_of_publish': '2024-01-15T14:00:20Z', 'video_duration': 'PT14M6S', 'views_count': '246612', 'comment_count': None, 'like_count': '16894', 'fav_count': '0', 'video_Definition': 'hd', 'Caption_status': 'false'}
# {'channel_name': 'manichow', 'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ', 'video_id': '_XxWxBaXCnY', 'video_tittle': 'one year of manichow 🎈', 'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/_XxWxBaXCnY/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/_XxWxBaXCnY/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/_XxWxBaXCnY/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/_XxWxBaXCnY/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/_XxWxBaXCnY/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'v_description': 'welcome to my youtube channel guys! hope you like my videos 😉🥰\nlike, share and subscribe for more content 😄🤪💥', 'video_tags': None, 'v_date_of_publish': '2023-12-31T13:48:03Z', 'video_duration': 'PT9M42S', 'views_count': '282863', 'comment_count': None, 'like_count': '23588', 'fav_count': '0', 'video_Definition': 'hd', 'Caption_status': 'false'}
# {'channel_name': 'manichow', 'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ', 'video_id': 'cv0ZHaplbIY', 'video_tittle': 'i make you a sandwich and rant about hate 🤓', 'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/cv0ZHaplbIY/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/cv0ZHaplbIY/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/cv0ZHaplbIY/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/cv0ZHaplbIY/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/cv0ZHaplbIY/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'v_description': 'thakida thakida thakida thakida thaaa 🕺💥\n\nmy instagram: https://www.instagram.com/manichoww/', 'video_tags': None, 'v_date_of_publish': '2023-12-25T14:00:30Z', 'video_duration': 'PT14M21S', 'views_count': '377171', 'comment_count': None, 'like_count': '30584', 'fav_count': '0', 'video_Definition': 'hd', 'Caption_status': 'false'}
# {'channel_name': 'manichow', 'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ', 'video_id': 'b50LfkF5wio', 'video_tittle': 'back to the kitchen ⏪', 'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/b50LfkF5wio/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/b50LfkF5wio/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/b50LfkF5wio/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/b50LfkF5wio/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/b50LfkF5wio/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'v_description': 'yaar ennai samaika vittadhu??!', 'video_tags': None, 'v_date_of_publish': '2023-12-19T13:30:16Z', 'video_duration': 'PT15M34S', 'views_count': '637836', 'comment_count': None, 'like_count': '42534', 'fav_count': '0', 'video_Definition': 'hd', 'Caption_status': 'false'}
# {'channel_name': 'manichow', 'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ', 'video_id': 'UO0RvM6K0Oc', 'video_tittle': 'i speak in english, i slap myself 👍', 'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/UO0RvM6K0Oc/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/UO0RvM6K0Oc/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/UO0RvM6K0Oc/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/UO0RvM6K0Oc/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/UO0RvM6K0Oc/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'v_description': '*நான் ஆங்கிலத்தில் பேசினால், என்னை நான் அறைந்து விடுவேன் 👍', 'video_tags': None, 'v_date_of_publish': '2023-11-23T14:00:30Z', 'video_duration': 'PT9M1S', 'views_count': '1569307', 'comment_count': None, 'like_count': '99389', 'fav_count': '0', 'video_Definition': 'hd', 'Caption_status': 'false'}
# {'channel_name': 'manichow', 'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ', 'video_id': 'ga9qgTKSN90', 'video_tittle': 'indian rizzlords 🗿', 'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/ga9qgTKSN90/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/ga9qgTKSN90/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/ga9qgTKSN90/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/ga9qgTKSN90/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/ga9qgTKSN90/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'v_description': "i wish to be colonised once again, this ain't it 🙏", 'video_tags': None, 'v_date_of_publish': '2023-11-07T14:11:27Z', 'video_duration': 'PT15M55S', 'views_count': '462049', 'comment_count': None, 'like_count': '24646', 'fav_count': '0', 'video_Definition': 'hd', 'Caption_status': 'false'}
# {'channel_name': 'manichow', 'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ', 'video_id': '7JVFmpJ3v48', 'video_tittle': 'lets talk about concerts in chennai 🕺', 'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/7JVFmpJ3v48/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/7JVFmpJ3v48/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/7JVFmpJ3v48/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/7JVFmpJ3v48/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/7JVFmpJ3v48/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'v_description': 'thilele podu thileley 😙🕺', 'video_tags': None, 'v_date_of_publish': '2023-10-05T14:00:09Z', 'video_duration': 'PT13M16S', 'views_count': '156234', 'comment_count': None, 'like_count': '8652', 'fav_count': '0', 'video_Definition': 'hd', 'Caption_status': 'false'}
# {'channel_name': 'manichow', 'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ', 'video_id': '6gKGQlJ0cOA', 'video_tittle': 'manichow watches another button video👍', 'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/6gKGQlJ0cOA/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/6gKGQlJ0cOA/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/6gKGQlJ0cOA/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/6gKGQlJ0cOA/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/6gKGQlJ0cOA/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'v_description': 'screw the button, come to me for matchmaking / couples therapy ✅', 'video_tags': None, 'v_date_of_publish': '2023-09-22T14:00:28Z', 'video_duration': 'PT12M54S', 'views_count': '158140', 'comment_count': None, 'like_count': '10293', 'fav_count': '0', 'video_Definition': 'hd', 'Caption_status': 'false'}
# {'channel_name': 'manichow', 'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ', 'video_id': 'VAz1cqW9RjM', 'video_tittle': 'the pressure to always stay on trend 👩\u200d🦯', 'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/VAz1cqW9RjM/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/VAz1cqW9RjM/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/VAz1cqW9RjM/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/VAz1cqW9RjM/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/VAz1cqW9RjM/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'v_description': 'this video may or may not be a defence mechanism against people who call me cringe 😙\nand yes, cringe panunga vaazhka nalla irukum 🥰', 'video_tags': None, 'v_date_of_publish': '2023-08-23T14:15:26Z', 'video_duration': 'PT8M45S', 'views_count': '124272', 'comment_count': None, 'like_count': '8519', 'fav_count': '0', 'video_Definition': 'hd', 'Caption_status': 'false'}
# {'channel_name': 'manichow', 'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ', 'video_id': '4rvoO920Awo', 'video_tittle': 'reacting to youtube comments cause im famous now 😙💅', 'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/4rvoO920Awo/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/4rvoO920Awo/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/4rvoO920Awo/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/4rvoO920Awo/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/4rvoO920Awo/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'v_description': 'if your comment\'s gonna contain "akka" in it, keep it to yourself.\n\n\n\nchumma sonnen go ahead and post it, i can use the engagement 😙👍', 'video_tags': None, 'v_date_of_publish': '2023-08-05T15:16:12Z', 'video_duration': 'PT10M19S', 'views_count': '240339', 'comment_count': None, 'like_count': '16028', 'fav_count': '0', 'video_Definition': 'hd', 'Caption_status': 'false'}
# {'channel_name': 'manichow', 'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ', 'video_id': 'kwPdbzIwdgY', 'video_tittle': 'reels paaklama champions 😋', 'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/kwPdbzIwdgY/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/kwPdbzIwdgY/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/kwPdbzIwdgY/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/kwPdbzIwdgY/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/kwPdbzIwdgY/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'v_description': 'indha video ah like panikonga apdiye subscribe um sethu panikonga champions 🥰', 'video_tags': None, 'v_date_of_publish': '2023-07-18T14:30:08Z', 'video_duration': 'PT8M54S', 'views_count': '918022', 'comment_count': None, 'like_count': '45571', 'fav_count': '0', 'video_Definition': 'hd', 'Caption_status': 'false'}
# {'channel_name': 'manichow', 'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ', 'video_id': 'CAWuFGmuXlE', 'video_tittle': 'project makeover ads are getting out of hand !', 'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/CAWuFGmuXlE/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/CAWuFGmuXlE/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/CAWuFGmuXlE/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/CAWuFGmuXlE/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/CAWuFGmuXlE/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'v_description': 'who let them cook?', 'video_tags': None, 'v_date_of_publish': '2023-06-30T13:56:10Z', 'video_duration': 'PT10M21S', 'views_count': '95872', 'comment_count': None, 'like_count': '4944', 'fav_count': '0', 'video_Definition': 'hd', 'Caption_status': 'false'}
# {'channel_name': 'manichow', 'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ', 'video_id': 'MlW8d0C9220', 'video_tittle': 'reviewing IIFA awards 2023 outfits 😙🎀', 'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/MlW8d0C9220/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/MlW8d0C9220/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/MlW8d0C9220/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/MlW8d0C9220/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/MlW8d0C9220/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'v_description': '"it\'s not that bad, it\'s good"', 'video_tags': None, 'v_date_of_publish': '2023-06-17T14:01:40Z', 'video_duration': 'PT10M40S', 'views_count': '135404', 'comment_count': None, 'like_count': '6522', 'fav_count': '0', 'video_Definition': 'hd', 'Caption_status': 'false'}
# {'channel_name': 'manichow', 'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ', 'video_id': 'Waf9QE0zeFc', 'video_tittle': 'deranged makeover + modern love chennai review 💄✨', 'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/Waf9QE0zeFc/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/Waf9QE0zeFc/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/Waf9QE0zeFc/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/Waf9QE0zeFc/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/Waf9QE0zeFc/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'v_description': '"vazhkaila minor inconvenience iruklam, vazhkaye minor inconvenience ah iruka kudadhu" - priviledged 19 year old on youtube (me)\n.\n.\nfilm review is just for like 3 mins towards the end , clickbait kaga title la potruken 🤝', 'video_tags': None, 'v_date_of_publish': '2023-06-01T15:34:48Z', 'video_duration': 'PT11M48S', 'views_count': '96186', 'comment_count': None, 'like_count': '4211', 'fav_count': '0', 'video_Definition': 'hd', 'Caption_status': 'false'}
# {'channel_name': 'manichow', 'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ', 'video_id': 'J1kKo_we7pA', 'video_tittle': 'kutti manichow kadhaigal :3', 'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/J1kKo_we7pA/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/J1kKo_we7pA/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/J1kKo_we7pA/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/J1kKo_we7pA/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/J1kKo_we7pA/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'v_description': 'ozhungu mariyadhaya childhood memory ah comment pannu, illana attack dhan 😡🔪', 'video_tags': None, 'v_date_of_publish': '2023-05-19T14:21:23Z', 'video_duration': 'PT9M53S', 'views_count': '111924', 'comment_count': None, 'like_count': '5976', 'fav_count': '0', 'video_Definition': 'hd', 'Caption_status': 'false'}
# {'channel_name': 'manichow', 'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ', 'video_id': '6MFWw-01hHQ', 'video_tittle': 'pov : your highschool bully just became a finance advisor', 'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/6MFWw-01hHQ/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/6MFWw-01hHQ/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/6MFWw-01hHQ/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/6MFWw-01hHQ/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/6MFWw-01hHQ/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'v_description': '"nee saavum podhukuda edhuvume anubavikaama dummy ah dhan saava"\n- goddamn_queen_ , 2023 🛐', 'video_tags': None, 'v_date_of_publish': '2023-05-03T14:30:13Z', 'video_duration': 'PT11M48S', 'views_count': '328295', 'comment_count': None, 'like_count': '14131', 'fav_count': '0', 'video_Definition': 'hd', 'Caption_status': 'false'}
# {'channel_name': 'manichow', 'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ', 'video_id': 'yP0KKqnzHYw', 'video_tittle': "spoof news (it's my college project)", 'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/yP0KKqnzHYw/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/yP0KKqnzHYw/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/yP0KKqnzHYw/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/yP0KKqnzHYw/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/yP0KKqnzHYw/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'v_description': 'call me ms. sustainable the way i reuse every piece of content i ever make.', 'video_tags': None, 'v_date_of_publish': '2023-04-19T14:06:57Z', 'video_duration': 'PT5M14S', 'views_count': '45428', 'comment_count': None, 'like_count': '2622', 'fav_count': '0', 'video_Definition': 'hd', 'Caption_status': 'false'}
# {'channel_name': 'manichow', 'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ', 'video_id': 'iVwtFofco0Y', 'video_tittle': 'watching ridiculous game ads + playing one of them', 'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/iVwtFofco0Y/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/iVwtFofco0Y/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/iVwtFofco0Y/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/iVwtFofco0Y/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/iVwtFofco0Y/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'v_description': 'I thought nothing could top the absurdity of my fever dreams, I was wrong.', 'video_tags': None, 'v_date_of_publish': '2023-04-13T13:39:15Z', 'video_duration': 'PT15M53S', 'views_count': '124940', 'comment_count': None, 'like_count': '7404', 'fav_count': '0', 'video_Definition': 'hd', 'Caption_status': 'false'}
# {'channel_name': 'manichow', 'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ', 'video_id': 'zzbi1eLLIpQ', 'video_tittle': 'is he the certified lover boi of kerala?', 'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/zzbi1eLLIpQ/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/zzbi1eLLIpQ/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/zzbi1eLLIpQ/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/zzbi1eLLIpQ/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/zzbi1eLLIpQ/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'v_description': 'me when the women \nhttps://www.instagram.com/reel/CmEWlhtJbDn/?utm_source=ig_web_copy_link😙❤️', 'video_tags': None, 'v_date_of_publish': '2023-03-17T14:30:02Z', 'video_duration': 'PT13M30S', 'views_count': '204941', 'comment_count': None, 'like_count': '10426', 'fav_count': '0', 'video_Definition': 'hd', 'Caption_status': 'false'}
# {'channel_name': 'manichow', 'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ', 'video_id': 'SkqWj1FW2bE', 'video_tittle': 'why do movies glorify tf out of college life?', 'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/SkqWj1FW2bE/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/SkqWj1FW2bE/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/SkqWj1FW2bE/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/SkqWj1FW2bE/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/SkqWj1FW2bE/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'v_description': "this is'nt very hip college student of me i apologise 😔 🙏", 'video_tags': None, 'v_date_of_publish': '2023-02-26T13:30:09Z', 'video_duration': 'PT11M7S', 'views_count': '136389', 'comment_count': None, 'like_count': '6728', 'fav_count': '0', 'video_Definition': 'hd', 'Caption_status': 'false'}
# {'channel_name': 'manichow', 'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ', 'video_id': 'RaksVyGbM4k', 'video_tittle': 'i found the most ruthless show ever!? (i like watching people in pain)', 'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/RaksVyGbM4k/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/RaksVyGbM4k/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/RaksVyGbM4k/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/RaksVyGbM4k/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/RaksVyGbM4k/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'v_description': 'we can be friends if you want 🤝', 'video_tags': None, 'v_date_of_publish': '2023-02-16T13:37:30Z', 'video_duration': 'PT15M43S', 'views_count': '42430', 'comment_count': None, 'like_count': '2489', 'fav_count': '0', 'video_Definition': 'hd', 'Caption_status': 'false'}
# {'channel_name': 'manichow', 'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ', 'video_id': 'dlvdW9iU5nk', 'video_tittle': 'certified lover boi of tamilnadu', 'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/dlvdW9iU5nk/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/dlvdW9iU5nk/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/dlvdW9iU5nk/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/dlvdW9iU5nk/sddefault.jpg', 'width': 640, 'height': 480}}, 'v_description': 'description? this is how my friend described him : "POV softcore por- pork✅ panuvaney reels la"', 'video_tags': None, 'v_date_of_publish': '2023-02-01T15:37:40Z', 'video_duration': 'PT11M59S', 'views_count': '210424', 'comment_count': None, 'like_count': '9846', 'fav_count': '0', 'video_Definition': 'hd', 'Caption_status': 'false'}
# {'channel_name': 'manichow', 'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ', 'video_id': '3TtNdO4A_2g', 'video_tittle': 'why do we have zero road sense?', 'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/3TtNdO4A_2g/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/3TtNdO4A_2g/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/3TtNdO4A_2g/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/3TtNdO4A_2g/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/3TtNdO4A_2g/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'v_description': 'Indian drivers took "irupadhu oru lifeu adichuka cheers" in the wrong sense.', 'video_tags': None, 'v_date_of_publish': '2023-01-23T15:36:26Z', 'video_duration': 'PT8M2S', 'views_count': '29020', 'comment_count': None, 'like_count': '1791', 'fav_count': '0', 'video_Definition': 'hd', 'Caption_status': 'false'}
# {'channel_name': 'manichow', 'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ', 'video_id': 'WnkQnKuQiH8', 'video_tittle': 'The Best Motivational Speaker on Instagram', 'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/WnkQnKuQiH8/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/WnkQnKuQiH8/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/WnkQnKuQiH8/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/WnkQnKuQiH8/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/WnkQnKuQiH8/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'v_description': "I'm gonna motivate you so bad, you'll finally get a life.", 'video_tags': None, 'v_date_of_publish': '2023-01-14T13:28:20Z', 'video_duration': 'PT5M53S', 'views_count': '44869', 'comment_count': None, 'like_count': '2059', 'fav_count': '0', 'video_Definition': 'hd', 'Caption_status': 'false'}
# {'channel_name': 'manichow', 'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ', 'video_id': 'pPwnwpoWp3I', 'video_tittle': 'new year, new hair, possibly new me?', 'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/pPwnwpoWp3I/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/pPwnwpoWp3I/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/pPwnwpoWp3I/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/pPwnwpoWp3I/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/pPwnwpoWp3I/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'v_description': 'she found the words "rather" and "enna porutha varikum" and never shut up since.\n.\n\n\n\n\n\n\n\n\n.\nsincere apologies for the poorly edited thumbnail 🙏', 'video_tags': None, 'v_date_of_publish': '2023-01-06T14:50:07Z', 'video_duration': 'PT11M20S', 'views_count': '27736', 'comment_count': None, 'like_count': '1496', 'fav_count': '0', 'video_Definition': 'hd', 'Caption_status': 'false'}
# {'channel_name': 'manichow', 'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ', 'video_id': 'HiI-bSZzGDM', 'video_tittle': 'scrolling mindlessly', 'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/HiI-bSZzGDM/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/HiI-bSZzGDM/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/HiI-bSZzGDM/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/HiI-bSZzGDM/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/HiI-bSZzGDM/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'v_description': 'embarrassing myself to create the illusion of productivity 🗿', 'video_tags': None, 'v_date_of_publish': '2022-12-30T13:33:23Z', 'video_duration': 'PT7M4S', 'views_count': '87726', 'comment_count': None, 'like_count': '5409', 'fav_count': '0', 'video_Definition': 'hd', 'Caption_status': 'false'}

# %%
##getting video information 
def get_video_information(video_Ids_channel):
    video_data = []
    for video_id in video_Ids_channel:
        request = youtube.videos().list(
            part="snippet,ContentDetails,statistics",
            id=video_id
        )
        response = request.execute()
        for item in response['items']:
            video_info = dict(
                channel_name=item['snippet']['channelTitle'],
                channel_id=item['snippet']['channelId'],
                video_id=item['id'],
                video_tittle=item['snippet']['title'],
                v_thumbnail=item['snippet']['thumbnails'],
                v_description=item['snippet']['description'],
                video_tags=item.get('tags'),
                v_date_of_publish=item['snippet']['publishedAt'],
                video_duration=item['contentDetails']['duration'],
                views_count=item['statistics']['viewCount'],
                comment_count= item['statistics'].get('commentCount', 0),
                like_count=item['statistics']['likeCount'],
                fav_count=item['statistics']['favoriteCount'],
                video_Definition=item['contentDetails']['definition'],
                Caption_status=item['contentDetails']['caption']
            )
            video_data.append(video_info)
    return video_data

##if any items not available use ##get function eg video_tags=item.get('tags')

# %%
video_details=get_video_information(video_Ids_channel)
video_details
# Out:
# [{'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'SvKssslvta4',
#   'video_tittle': 'sillarayai sedhara vitten 🛵💥',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/SvKssslvta4/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/SvKssslvta4/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/SvKssslvta4/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/SvKssslvta4/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/SvKssslvta4/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': "pls don't bully me with more mutti jokes :(",
#   'video_tags': None,
#   'v_date_of_publish': '2024-04-22T14:08:36Z',
#   'video_duration': 'PT13M39S',
#   'views_count': '210778',
#   'comment_count': '1169',
#   'like_count': '16186',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'T8s3QOpCX9A',
#   'video_tittle': "✨influencer's era✨",
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/T8s3QOpCX9A/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/T8s3QOpCX9A/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/T8s3QOpCX9A/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/T8s3QOpCX9A/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/T8s3QOpCX9A/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'ennayum ipl commentary koopdunga 😋',
#   'video_tags': None,
#   'v_date_of_publish': '2024-04-16T13:31:06Z',
#   'video_duration': 'PT16M4S',
#   'views_count': '425348',
#   'comment_count': '2435',
#   'like_count': '33818',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'Hf1KFD98nx0',
#   'video_tittle': 'who let them cook🥸?',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/Hf1KFD98nx0/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/Hf1KFD98nx0/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/Hf1KFD98nx0/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/Hf1KFD98nx0/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/Hf1KFD98nx0/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'social anxiety is scared of them 💀👍',
#   'video_tags': None,
#   'v_date_of_publish': '2024-03-06T14:00:10Z',
#   'video_duration': 'PT9M35S',
#   'views_count': '462089',
#   'comment_count': '1351',
#   'like_count': '26345',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'NEqmKa-e9vE',
#   'video_tittle': 'is it really yes all men?',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/NEqmKa-e9vE/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/NEqmKa-e9vE/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/NEqmKa-e9vE/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/NEqmKa-e9vE/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/NEqmKa-e9vE/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': "if I'm wrong anywhere in the video, please let me know in the comments. Post your views on this as well.",
#   'video_tags': None,
#   'v_date_of_publish': '2024-02-18T13:47:10Z',
#   'video_duration': 'PT18M24S',
#   'views_count': '374559',
#   'comment_count': '3213',
#   'like_count': '34653',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'L7cAq6KyR18',
#   'video_tittle': 'kutti manichow kadhaigal 2 🎀✨',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/L7cAq6KyR18/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/L7cAq6KyR18/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/L7cAq6KyR18/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/L7cAq6KyR18/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/L7cAq6KyR18/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'tap la sudu thanni vardhu😥😲💥‼️\n\n\n\n\nInstagram : https://www.instagram.com/manichoww/',
#   'video_tags': None,
#   'v_date_of_publish': '2024-02-04T14:00:19Z',
#   'video_duration': 'PT11M29S',
#   'views_count': '154892',
#   'comment_count': '551',
#   'like_count': '11483',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'YHnWK0gPNpM',
#   'video_tittle': 'na ambani aaga poren💸‼️',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/YHnWK0gPNpM/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/YHnWK0gPNpM/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/YHnWK0gPNpM/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/YHnWK0gPNpM/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/YHnWK0gPNpM/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'janavary 31st vandha dhananga new year kondaada mudiyum👺‼️\n\n\n\ninstagram : https://www.instagram.com/manichoww',
#   'video_tags': None,
#   'v_date_of_publish': '2024-01-15T14:00:20Z',
#   'video_duration': 'PT14M6S',
#   'views_count': '246612',
#   'comment_count': '924',
#   'like_count': '16894',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': '_XxWxBaXCnY',
#   'video_tittle': 'one year of manichow 🎈',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/_XxWxBaXCnY/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/_XxWxBaXCnY/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/_XxWxBaXCnY/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/_XxWxBaXCnY/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/_XxWxBaXCnY/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'welcome to my youtube channel guys! hope you like my videos 😉🥰\nlike, share and subscribe for more content 😄🤪💥',
#   'video_tags': None,
#   'v_date_of_publish': '2023-12-31T13:48:03Z',
#   'video_duration': 'PT9M42S',
#   'views_count': '282863',
#   'comment_count': '994',
#   'like_count': '23588',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'cv0ZHaplbIY',
#   'video_tittle': 'i make you a sandwich and rant about hate 🤓',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/cv0ZHaplbIY/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/cv0ZHaplbIY/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/cv0ZHaplbIY/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/cv0ZHaplbIY/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/cv0ZHaplbIY/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'thakida thakida thakida thakida thaaa 🕺💥\n\nmy instagram: https://www.instagram.com/manichoww/',
#   'video_tags': None,
#   'v_date_of_publish': '2023-12-25T14:00:30Z',
#   'video_duration': 'PT14M21S',
#   'views_count': '377171',
#   'comment_count': '1964',
#   'like_count': '30584',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'b50LfkF5wio',
#   'video_tittle': 'back to the kitchen ⏪',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/b50LfkF5wio/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/b50LfkF5wio/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/b50LfkF5wio/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/b50LfkF5wio/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/b50LfkF5wio/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'yaar ennai samaika vittadhu??!',
#   'video_tags': None,
#   'v_date_of_publish': '2023-12-19T13:30:16Z',
#   'video_duration': 'PT15M34S',
#   'views_count': '637836',
#   'comment_count': '2547',
#   'like_count': '42534',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'UO0RvM6K0Oc',
#   'video_tittle': 'i speak in english, i slap myself 👍',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/UO0RvM6K0Oc/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/UO0RvM6K0Oc/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/UO0RvM6K0Oc/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/UO0RvM6K0Oc/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/UO0RvM6K0Oc/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': '*நான் ஆங்கிலத்தில் பேசினால், என்னை நான் அறைந்து விடுவேன் 👍',
#   'video_tags': None,
#   'v_date_of_publish': '2023-11-23T14:00:30Z',
#   'video_duration': 'PT9M1S',
#   'views_count': '1569307',
#   'comment_count': '8032',
#   'like_count': '99389',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'ga9qgTKSN90',
#   'video_tittle': 'indian rizzlords 🗿',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/ga9qgTKSN90/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/ga9qgTKSN90/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/ga9qgTKSN90/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/ga9qgTKSN90/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/ga9qgTKSN90/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': "i wish to be colonised once again, this ain't it 🙏",
#   'video_tags': None,
#   'v_date_of_publish': '2023-11-07T14:11:27Z',
#   'video_duration': 'PT15M55S',
#   'views_count': '462049',
#   'comment_count': '1121',
#   'like_count': '24646',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': '7JVFmpJ3v48',
#   'video_tittle': 'lets talk about concerts in chennai 🕺',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/7JVFmpJ3v48/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/7JVFmpJ3v48/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/7JVFmpJ3v48/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/7JVFmpJ3v48/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/7JVFmpJ3v48/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'thilele podu thileley 😙🕺',
#   'video_tags': None,
#   'v_date_of_publish': '2023-10-05T14:00:09Z',
#   'video_duration': 'PT13M16S',
#   'views_count': '156234',
#   'comment_count': '357',
#   'like_count': '8652',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': '6gKGQlJ0cOA',
#   'video_tittle': 'manichow watches another button video👍',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/6gKGQlJ0cOA/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/6gKGQlJ0cOA/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/6gKGQlJ0cOA/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/6gKGQlJ0cOA/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/6gKGQlJ0cOA/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'screw the button, come to me for matchmaking / couples therapy ✅',
#   'video_tags': None,
#   'v_date_of_publish': '2023-09-22T14:00:28Z',
#   'video_duration': 'PT12M54S',
#   'views_count': '158140',
#   'comment_count': '463',
#   'like_count': '10293',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'VAz1cqW9RjM',
#   'video_tittle': 'the pressure to always stay on trend 👩\u200d🦯',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/VAz1cqW9RjM/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/VAz1cqW9RjM/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/VAz1cqW9RjM/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/VAz1cqW9RjM/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/VAz1cqW9RjM/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'this video may or may not be a defence mechanism against people who call me cringe 😙\nand yes, cringe panunga vaazhka nalla irukum 🥰',
#   'video_tags': None,
#   'v_date_of_publish': '2023-08-23T14:15:26Z',
#   'video_duration': 'PT8M45S',
#   'views_count': '124272',
#   'comment_count': '796',
#   'like_count': '8519',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': '4rvoO920Awo',
#   'video_tittle': 'reacting to youtube comments cause im famous now 😙💅',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/4rvoO920Awo/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/4rvoO920Awo/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/4rvoO920Awo/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/4rvoO920Awo/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/4rvoO920Awo/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'if your comment\'s gonna contain "akka" in it, keep it to yourself.\n\n\n\nchumma sonnen go ahead and post it, i can use the engagement 😙👍',
#   'video_tags': None,
#   'v_date_of_publish': '2023-08-05T15:16:12Z',
#   'video_duration': 'PT10M19S',
#   'views_count': '240339',
#   'comment_count': '1289',
#   'like_count': '16028',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'kwPdbzIwdgY',
#   'video_tittle': 'reels paaklama champions 😋',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/kwPdbzIwdgY/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/kwPdbzIwdgY/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/kwPdbzIwdgY/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/kwPdbzIwdgY/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/kwPdbzIwdgY/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'indha video ah like panikonga apdiye subscribe um sethu panikonga champions 🥰',
#   'video_tags': None,
#   'v_date_of_publish': '2023-07-18T14:30:08Z',
#   'video_duration': 'PT8M54S',
#   'views_count': '918022',
#   'comment_count': '1884',
#   'like_count': '45571',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'CAWuFGmuXlE',
#   'video_tittle': 'project makeover ads are getting out of hand !',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/CAWuFGmuXlE/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/CAWuFGmuXlE/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/CAWuFGmuXlE/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/CAWuFGmuXlE/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/CAWuFGmuXlE/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'who let them cook?',
#   'video_tags': None,
#   'v_date_of_publish': '2023-06-30T13:56:10Z',
#   'video_duration': 'PT10M21S',
#   'views_count': '95872',
#   'comment_count': '261',
#   'like_count': '4944',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'MlW8d0C9220',
#   'video_tittle': 'reviewing IIFA awards 2023 outfits 😙🎀',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/MlW8d0C9220/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/MlW8d0C9220/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/MlW8d0C9220/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/MlW8d0C9220/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/MlW8d0C9220/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': '"it\'s not that bad, it\'s good"',
#   'video_tags': None,
#   'v_date_of_publish': '2023-06-17T14:01:40Z',
#   'video_duration': 'PT10M40S',
#   'views_count': '135404',
#   'comment_count': '242',
#   'like_count': '6522',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'Waf9QE0zeFc',
#   'video_tittle': 'deranged makeover + modern love chennai review 💄✨',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/Waf9QE0zeFc/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/Waf9QE0zeFc/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/Waf9QE0zeFc/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/Waf9QE0zeFc/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/Waf9QE0zeFc/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': '"vazhkaila minor inconvenience iruklam, vazhkaye minor inconvenience ah iruka kudadhu" - priviledged 19 year old on youtube (me)\n.\n.\nfilm review is just for like 3 mins towards the end , clickbait kaga title la potruken 🤝',
#   'video_tags': None,
#   'v_date_of_publish': '2023-06-01T15:34:48Z',
#   'video_duration': 'PT11M48S',
#   'views_count': '96186',
#   'comment_count': '172',
#   'like_count': '4211',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'J1kKo_we7pA',
#   'video_tittle': 'kutti manichow kadhaigal :3',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/J1kKo_we7pA/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/J1kKo_we7pA/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/J1kKo_we7pA/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/J1kKo_we7pA/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/J1kKo_we7pA/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'ozhungu mariyadhaya childhood memory ah comment pannu, illana attack dhan 😡🔪',
#   'video_tags': None,
#   'v_date_of_publish': '2023-05-19T14:21:23Z',
#   'video_duration': 'PT9M53S',
#   'views_count': '111924',
#   'comment_count': '436',
#   'like_count': '5976',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': '6MFWw-01hHQ',
#   'video_tittle': 'pov : your highschool bully just became a finance advisor',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/6MFWw-01hHQ/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/6MFWw-01hHQ/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/6MFWw-01hHQ/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/6MFWw-01hHQ/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/6MFWw-01hHQ/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': '"nee saavum podhukuda edhuvume anubavikaama dummy ah dhan saava"\n- goddamn_queen_ , 2023 🛐',
#   'video_tags': None,
#   'v_date_of_publish': '2023-05-03T14:30:13Z',
#   'video_duration': 'PT11M48S',
#   'views_count': '328295',
#   'comment_count': '537',
#   'like_count': '14131',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'yP0KKqnzHYw',
#   'video_tittle': "spoof news (it's my college project)",
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/yP0KKqnzHYw/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/yP0KKqnzHYw/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/yP0KKqnzHYw/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/yP0KKqnzHYw/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/yP0KKqnzHYw/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'call me ms. sustainable the way i reuse every piece of content i ever make.',
#   'video_tags': None,
#   'v_date_of_publish': '2023-04-19T14:06:57Z',
#   'video_duration': 'PT5M14S',
#   'views_count': '45428',
#   'comment_count': '86',
#   'like_count': '2622',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'iVwtFofco0Y',
#   'video_tittle': 'watching ridiculous game ads + playing one of them',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/iVwtFofco0Y/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/iVwtFofco0Y/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/iVwtFofco0Y/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/iVwtFofco0Y/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/iVwtFofco0Y/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'I thought nothing could top the absurdity of my fever dreams, I was wrong.',
#   'video_tags': None,
#   'v_date_of_publish': '2023-04-13T13:39:15Z',
#   'video_duration': 'PT15M53S',
#   'views_count': '124940',
#   'comment_count': '204',
#   'like_count': '7404',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'zzbi1eLLIpQ',
#   'video_tittle': 'is he the certified lover boi of kerala?',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/zzbi1eLLIpQ/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/zzbi1eLLIpQ/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/zzbi1eLLIpQ/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/zzbi1eLLIpQ/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/zzbi1eLLIpQ/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'me when the women \nhttps://www.instagram.com/reel/CmEWlhtJbDn/?utm_source=ig_web_copy_link😙❤️',
#   'video_tags': None,
#   'v_date_of_publish': '2023-03-17T14:30:02Z',
#   'video_duration': 'PT13M30S',
#   'views_count': '204941',
#   'comment_count': '388',
#   'like_count': '10426',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'SkqWj1FW2bE',
#   'video_tittle': 'why do movies glorify tf out of college life?',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/SkqWj1FW2bE/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/SkqWj1FW2bE/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/SkqWj1FW2bE/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/SkqWj1FW2bE/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/SkqWj1FW2bE/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': "this is'nt very hip college student of me i apologise 😔 🙏",
#   'video_tags': None,
#   'v_date_of_publish': '2023-02-26T13:30:09Z',
#   'video_duration': 'PT11M7S',
#   'views_count': '136389',
#   'comment_count': '311',
#   'like_count': '6728',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'RaksVyGbM4k',
#   'video_tittle': 'i found the most ruthless show ever!? (i like watching people in pain)',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/RaksVyGbM4k/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/RaksVyGbM4k/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/RaksVyGbM4k/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/RaksVyGbM4k/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/RaksVyGbM4k/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'we can be friends if you want 🤝',
#   'video_tags': None,
#   'v_date_of_publish': '2023-02-16T13:37:30Z',
#   'video_duration': 'PT15M43S',
#   'views_count': '42430',
#   'comment_count': '67',
#   'like_count': '2489',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'dlvdW9iU5nk',
#   'video_tittle': 'certified lover boi of tamilnadu',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/dlvdW9iU5nk/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/dlvdW9iU5nk/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/dlvdW9iU5nk/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/dlvdW9iU5nk/sddefault.jpg',
#     'width': 640,
#     'height': 480}},
#   'v_description': 'description? this is how my friend described him : "POV softcore por- pork✅ panuvaney reels la"',
#   'video_tags': None,
#   'v_date_of_publish': '2023-02-01T15:37:40Z',
#   'video_duration': 'PT11M59S',
#   'views_count': '210424',
#   'comment_count': '371',
#   'like_count': '9846',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': '3TtNdO4A_2g',
#   'video_tittle': 'why do we have zero road sense?',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/3TtNdO4A_2g/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/3TtNdO4A_2g/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/3TtNdO4A_2g/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/3TtNdO4A_2g/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/3TtNdO4A_2g/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'Indian drivers took "irupadhu oru lifeu adichuka cheers" in the wrong sense.',
#   'video_tags': None,
#   'v_date_of_publish': '2023-01-23T15:36:26Z',
#   'video_duration': 'PT8M2S',
#   'views_count': '29020',
#   'comment_count': '73',
#   'like_count': '1791',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'WnkQnKuQiH8',
#   'video_tittle': 'The Best Motivational Speaker on Instagram',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/WnkQnKuQiH8/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/WnkQnKuQiH8/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/WnkQnKuQiH8/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/WnkQnKuQiH8/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/WnkQnKuQiH8/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': "I'm gonna motivate you so bad, you'll finally get a life.",
#   'video_tags': None,
#   'v_date_of_publish': '2023-01-14T13:28:20Z',
#   'video_duration': 'PT5M53S',
#   'views_count': '44869',
#   'comment_count': '61',
#   'like_count': '2059',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'pPwnwpoWp3I',
#   'video_tittle': 'new year, new hair, possibly new me?',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/pPwnwpoWp3I/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/pPwnwpoWp3I/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/pPwnwpoWp3I/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/pPwnwpoWp3I/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/pPwnwpoWp3I/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'she found the words "rather" and "enna porutha varikum" and never shut up since.\n.\n\n\n\n\n\n\n\n\n.\nsincere apologies for the poorly edited thumbnail 🙏',
#   'video_tags': None,
#   'v_date_of_publish': '2023-01-06T14:50:07Z',
#   'video_duration': 'PT11M20S',
#   'views_count': '27736',
#   'comment_count': '73',
#   'like_count': '1496',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'},
#  {'channel_name': 'manichow',
#   'channel_id': 'UCmrsodcsfoZyFwW_f-ZtvfQ',
#   'video_id': 'HiI-bSZzGDM',
#   'video_tittle': 'scrolling mindlessly',
#   'v_thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/HiI-bSZzGDM/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/HiI-bSZzGDM/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/HiI-bSZzGDM/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/HiI-bSZzGDM/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/HiI-bSZzGDM/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'v_description': 'embarrassing myself to create the illusion of productivity 🗿',
#   'video_tags': None,
#   'v_date_of_publish': '2022-12-30T13:33:23Z',
#   'video_duration': 'PT7M4S',
#   'views_count': '87726',
#   'comment_count': '181',
#   'like_count': '5409',
#   'fav_count': '0',
#   'video_Definition': 'hd',
#   'Caption_status': 'false'}]

# %%
len(video_details)
# Out:
# 31

# %%
##getting comment details

# %%
for video_id in video_Ids_channel:
    request=youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        maxResults=50
    )
    response=request.execute()
    for items in response["items"]:
        comment_info=dict(commenter_id=items['snippet']['topLevelComment']['id'],
                         video_id=items['snippet']['topLevelComment']['snippet']['videoId'],
                         comment_text=items['snippet']['topLevelComment']['snippet']['textDisplay'],
                         comment_author=items['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                         comment_time=items['snippet']['topLevelComment']['snippet']['publishedAt'],)

# %%
##if comment section turned off
def get_comment_details(videos_ids):
    comment_informations=[]
    try:
        for video_id in videos_ids:
            request=youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                maxResults=50
            )
            response=request.execute()
            for items in response["items"]:
                comment_data=dict(commenter_id=items['snippet']['topLevelComment']['id'],
                                 video_id=items['snippet']['topLevelComment']['snippet']['videoId'],
                                 comment_text=items['snippet']['topLevelComment']['snippet']['textDisplay'],
                                 comment_author=items['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                                 comment_time=items['snippet']['topLevelComment']['snippet']['publishedAt'],)
                comment_informations.append(comment_data)
    except:
        pass
    return  comment_informations

# %%
comment_details=get_comment_details(video_Ids_channel)

# %%
comment_details
# Out:
# [{'commenter_id': 'Ugw0iUanPK9X4y56q3t4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'First nu varavana Kottaya vettriruven✂️',
#   'comment_author': '@mouliharshu-yw8ng',
#   'comment_time': '2024-04-22T14:09:25Z'},
#  {'commenter_id': 'UgxbzCqZL7et88rZVk14AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'Story mattum vera 😂😂😂',
#   'comment_author': '@madhankiller3556',
#   'comment_time': '2024-04-28T15:23:05Z'},
#  {'commenter_id': 'Ugw0k4Vmb6pIcMrWJ3B4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'Ivangalum vilunthuda ga jk um viluthundan so for rendum perum onna ponaga loo😅😅',
#   'comment_author': '@madhankiller3556',
#   'comment_time': '2024-04-28T15:22:15Z'},
#  {'commenter_id': 'Ugwo3gQbsi3d-MulNxZ4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'In India, TN stands first in road accidents so drive safe friends.',
#   'comment_author': '@theguywhoace',
#   'comment_time': '2024-04-28T11:54:21Z'},
#  {'commenter_id': 'UgxuEAy7nO1HiVo_BBJ4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'who still remembers that chandramuki rajini scene 🤣🤣',
#   'comment_author': '@dikshithams5741',
#   'comment_time': '2024-04-28T10:47:07Z'},
#  {'commenter_id': 'Ugya5u9218KZk3_8Fn54AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'Watha back break purikkama direct ah front ah pota vilugama pinne😭',
#   'comment_author': '@sabhilash4129',
#   'comment_time': '2024-04-28T09:55:36Z'},
#  {'commenter_id': 'UgxMXA7OmjxF52G2nzl4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'So what is your name',
#   'comment_author': '@rolexop9780',
#   'comment_time': '2024-04-28T09:47:52Z'},
#  {'commenter_id': 'UgxAEuxKxTgL9giRR1l4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'you&quot;re mentioning bollineni right😂',
#   'comment_author': '@zell1538',
#   'comment_time': '2024-04-28T08:25:35Z'},
#  {'commenter_id': 'UgyaPEiqbNGjYOTAoix4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'Couple goals Jk &amp; Manichow got hurt at almost same time..😅💐',
#   'comment_author': '@tlsgaming3572',
#   'comment_time': '2024-04-28T07:28:05Z'},
#  {'commenter_id': 'UgyedqHVt1DcgCMY0gZ4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': '❤❤❤',
#   'comment_author': '@naveensuresh9690',
#   'comment_time': '2024-04-28T05:10:42Z'},
#  {'commenter_id': 'UgwdNYsxAVyV7GV1Ovl4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'Mutti sethavanga  nu solluvangaley oru vela athu ithuthaano 😂',
#   'comment_author': '@master_gaming6372',
#   'comment_time': '2024-04-28T05:05:23Z'},
#  {'commenter_id': 'Ugzihn9wIko9HtJy1rZ4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'Evlo naal video varala..',
#   'comment_author': '@satiristthamizhan5443',
#   'comment_time': '2024-04-27T19:27:38Z'},
#  {'commenter_id': 'Ugyx0rjuePNRzJZNeal4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'activa sales after this video📉',
#   'comment_author': '@srivignesh5339',
#   'comment_time': '2024-04-27T19:22:17Z'},
#  {'commenter_id': 'UgxcnN7UF1f-wZ_5oEF4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'Second hand vandiya... rendu masathula epdi break failure agum',
#   'comment_author': '@gokulk9370',
#   'comment_time': '2024-04-27T18:58:16Z'},
#  {'commenter_id': 'UgyY4fYX4uOx8Pa4ipR4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'Watch in 2x speed. Thank me later.🤝🏻',
#   'comment_author': '@AZ-ri6ex',
#   'comment_time': '2024-04-27T18:49:42Z'},
#  {'commenter_id': 'Ugx0rm1wzoThTRiB_J14AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'Nanum netha silra vangitu vanthen 😂',
#   'comment_author': '@balaji9287',
#   'comment_time': '2024-04-27T17:57:07Z'},
#  {'commenter_id': 'Ugxege8CTza-mxl0htd4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'Brain ku onnum agalala...😐😕',
#   'comment_author': '@hariprakashchandrasekar',
#   'comment_time': '2024-04-27T14:17:13Z'},
#  {'commenter_id': 'UgynXJnk5KL35N6yk4N4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'Vaikulla ethayo vchirukka mathiriye pesitturukku 😅😅😂',
#   'comment_author': '@p.rajendiranperumal2610',
#   'comment_time': '2024-04-27T12:34:53Z'},
#  {'commenter_id': 'UgzEmwsnnXx9SlWiAkp4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'I love girls fart💨🥰',
#   'comment_author': '@Paithiyakaaran466',
#   'comment_time': '2024-04-27T11:32:01Z'},
#  {'commenter_id': 'Ugxc6uhlPHuihp8YegJ4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'Batwoman 😅',
#   'comment_author': '@QueenBaby305',
#   'comment_time': '2024-04-27T10:41:15Z'},
#  {'commenter_id': 'UgyJ8cj_Ukmk-pP8-CF4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': '<a href="https://www.youtube.com/watch?v=SvKssslvta4&amp;t=687">11:27</a> arey chutiyaka wtf😂',
#   'comment_author': '@nikesh2k7',
#   'comment_time': '2024-04-27T10:29:56Z'},
#  {'commenter_id': 'UgzCrn0WKHUiETFFviB4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'Jk kuda kaavai la veltinglo🌚',
#   'comment_author': '@Meow_tiger',
#   'comment_time': '2024-04-27T09:06:27Z'},
#  {'commenter_id': 'UgxJ1OlI6srH1aaeFH14AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'You proudly said valiyavathu mairavathu 🤣anga nikra ka nee',
#   'comment_author': '@Madhumithakxr',
#   'comment_time': '2024-04-27T07:11:22Z'},
#  {'commenter_id': 'UgwNGfuciUrnMMKhHTt4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'Always use 70% front, 30% rear brakes while driving to avoid accidents',
#   'comment_author': '@hariprakash5077',
#   'comment_time': '2024-04-27T03:12:43Z'},
#  {'commenter_id': 'UgwLZshFjAa_wkG0BbJ4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': '<a href="https://www.youtube.com/watch?v=SvKssslvta4&amp;t=238">3:58</a> அழகி😊',
#   'comment_author': '@Krishna-pb2jk',
#   'comment_time': '2024-04-27T02:31:16Z'},
#  {'commenter_id': 'UgwM_R-anBBc299L8bV4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'Manichow make rasiganin rasigan troll one more',
#   'comment_author': '@JaganKumar-fl6pu',
#   'comment_time': '2024-04-27T02:09:17Z'},
#  {'commenter_id': 'UgzW7TYuYQBkC1fVtPR4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': '1.25x speed la patha tha vdo nalla iruku try panuvanga',
#   'comment_author': '@Voice_of_VJ.',
#   'comment_time': '2024-04-26T18:48:25Z'},
#  {'commenter_id': 'UgxhezoCJ-_5Osb_Ard4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'Evil eyes  people issue pro incident',
#   'comment_author': '@Subani-lg8wq',
#   'comment_time': '2024-04-26T18:19:16Z'},
#  {'commenter_id': 'UgwkCPe_1omByXiO-V54AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'Hi akka we don&#39;t happy we panic what happened to you rest pannunge nalla ungalukku aachum just skin tenji irukku but u will recover soon akka God will help you heal all wound....but for me I don&#39;t know 2 varusham plate edukka mudiyadu💔 enakku kaal todai elumbu irukku le broke so plate vachirukkange...while I accident I fainted while open eyes my bike in mosamana condition lost.',
#   'comment_author': '@divheshstarz592',
#   'comment_time': '2024-04-26T17:30:17Z'},
#  {'commenter_id': 'UgzDFdNy-CqUZsTUmnZ4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'Girls riding danger😅',
#   'comment_author': '@KarthiKarthi-kx3ie',
#   'comment_time': '2024-04-26T16:48:43Z'},
#  {'commenter_id': 'UgwOYp97YMn9Ubo0ow94AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'Oru video la trend aana athuku ipidi la panuvigala tension aaguthu nega pesarathu ... Geththa iruku nu ipidi pesarigala 🙄🙄',
#   'comment_author': '@sabbenasabbena5153',
#   'comment_time': '2024-04-26T16:32:23Z'},
#  {'commenter_id': 'UgwFH6Qbw3ll8Y2j0bF4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'The smartest women❤',
#   'comment_author': '@ArunKumar-lt3yu',
#   'comment_time': '2024-04-26T11:01:12Z'},
#  {'commenter_id': 'Ugz9AQE_dAqZ3H6DO9F4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'Activa stocks after this video 📉📉📉',
#   'comment_author': '@sanjay_gowtham2005',
#   'comment_time': '2024-04-26T10:36:58Z'},
#  {'commenter_id': 'UgySFNral1TtIAqrEEB4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'Glad you are fine.',
#   'comment_author': '@therik0077',
#   'comment_time': '2024-04-26T10:36:49Z'},
#  {'commenter_id': 'Ugz8yp-tt-oYa0Nb_RZ4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'I can feel the pain though😭 same break problem but in rain🤣🙃',
#   'comment_author': '@raji_2754',
#   'comment_time': '2024-04-26T09:30:28Z'},
#  {'commenter_id': 'Ugy36MIP3wP6SPvthsB4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'Aftersales of Activa📉😄',
#   'comment_author': '@rahuladiyapatham314',
#   'comment_time': '2024-04-26T05:00:44Z'},
#  {'commenter_id': 'UgwSxmYJ67xZUo0WRJx4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'The people mentioning JK are really annoying',
#   'comment_author': '@nixshax',
#   'comment_time': '2024-04-26T00:55:48Z'},
#  {'commenter_id': 'Ugxeatj3QuhslJ6RWrh4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': '🕳️🚶🏻',
#   'comment_author': '@RathnavelSanthanakumar',
#   'comment_time': '2024-04-25T20:42:40Z'},
#  {'commenter_id': 'Ugw_cHA7C5z5ZHklpOB4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'Sedharna sillreyellam JK pocket la vilundhirkum - Purinjavan pasta🤣',
#   'comment_author': '@110_commends_adikira_Lawrence',
#   'comment_time': '2024-04-25T18:23:52Z'},
#  {'commenter_id': 'UgzQVWVqwIsTegvomYd4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'Sedharna sillreyellam JK pocket la vilundhirkum - Purinjavan pasta🤣',
#   'comment_author': '@110_commends_adikira_Lawrence',
#   'comment_time': '2024-04-25T18:21:01Z'},
#  {'commenter_id': 'Ugx5X0mHaTkB_Lgu9VV4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'இது பைத்தியம்',
#   'comment_author': '@MohamedSettu-xh8tx',
#   'comment_time': '2024-04-25T17:47:16Z'},
#  {'commenter_id': 'UgzDUWdkxwfgeubcwr14AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'Women !☕',
#   'comment_author': '@ugeshkumar5063',
#   'comment_time': '2024-04-25T16:50:24Z'},
#  {'commenter_id': 'UgxNYpHDBDzJ2DDm5MJ4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'Toes🥺🥺',
#   'comment_author': '@48suriyas61',
#   'comment_time': '2024-04-25T16:30:30Z'},
#  {'commenter_id': 'UgxgJ3VhRf-eMywrIJR4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'I❤U 💕 Your eyes are very beautiful👀',
#   'comment_author': '@sheikhussain3884',
#   'comment_time': '2024-04-25T15:55:01Z'},
#  {'commenter_id': 'UgzXy3BfeTDxHaK4WFR4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'Enna couple goaals ah . <br>Jk bro ippa tha accident aaachuu <br>😂😂 funnn funny<br>Jk just kidding',
#   'comment_author': '@sumathisumathi1539',
#   'comment_time': '2024-04-25T15:13:50Z'},
#  {'commenter_id': 'UgztN-1ylkxuSqoyVzV4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'A2D kuda sendhu PC build panunga manisha 😅 pc ungaluku theva padum la',
#   'comment_author': '@content.create',
#   'comment_time': '2024-04-25T15:06:02Z'},
#  {'commenter_id': 'UgxYM--dnPMVtOOhfWt4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'Manichow: intha naal iniya naala irukku .. i think its a perfect day for driving <br>Activa : vaathiyarae lite ah nenju valikuthu <br>Manichow : Adangommala 😵\u200d💫😂',
#   'comment_author': '@dark_._demon',
#   'comment_time': '2024-04-25T14:20:29Z'},
#  {'commenter_id': 'UgyeuF2LWqO2h3QaQ214AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'Advocate vigneshkumar be like : Mela irukuravaru paathinga na avanga vandi la break uh pudikala nu video poturukaanga <br>Better Citizen Better Nation 🤣🤣😂😅',
#   'comment_author': '@yogesh7445',
#   'comment_time': '2024-04-25T14:19:40Z'},
#  {'commenter_id': 'UgwNE0e295uQEXrA9Zt4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'Akka is back',
#   'comment_author': '@damodharan1442',
#   'comment_time': '2024-04-25T13:28:16Z'},
#  {'commenter_id': 'UgzR5Jv1L3NzmTyp32t4AaABAg',
#   'video_id': 'SvKssslvta4',
#   'comment_text': 'JK &amp; Manichow',
#   'comment_author': '@MoorthyD24',
#   'comment_time': '2024-04-25T12:48:00Z'},
#  {'commenter_id': 'UgztutnVll_CKQhhYb94AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Ye mentioner rahh 🦅🦅🦅🗣️🗣️🗣️🗣️',
#   'comment_author': '@pranavandrithikavlogs5070',
#   'comment_time': '2024-04-28T16:11:08Z'},
#  {'commenter_id': 'UgzsI6Ph4slPWrvgjAV4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Avagala nee enna kalyanam pana porigala😅😂😂😂😂',
#   'comment_author': '@venkadeshg1894',
#   'comment_time': '2024-04-28T09:49:53Z'},
#  {'commenter_id': 'UgxKtNBjwRqZfn1BDYF4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Unaiya mari ella girls um 🌈  irupanagala',
#   'comment_author': '@SanjaiSelvan',
#   'comment_time': '2024-04-28T09:09:43Z'},
#  {'commenter_id': 'Ugzwx7a3PleZY12h_mh4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Avaruku puducha mari video podurathu unaku enga valikuthu 😡',
#   'comment_author': '@SanjaiSelvan',
#   'comment_time': '2024-04-28T09:08:20Z'},
#  {'commenter_id': 'UgzVy9SlPOnNTptKEP54AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Tharamana video..sis❤',
#   'comment_author': '@sumithsumith6306',
#   'comment_time': '2024-04-28T08:33:37Z'},
#  {'commenter_id': 'UgxJoDGuNw1IK7BwrmZ4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Onu sollurathuku ila kupta room kuda poiruvanga pola 🥶',
#   'comment_author': '@kk_wanted0463',
#   'comment_time': '2024-04-28T07:32:36Z'},
#  {'commenter_id': 'Ugw750tRxRUGoxzG5wN4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Kalyanam pannikalama 😁🌹😊',
#   'comment_author': '@majorkantharun4835',
#   'comment_time': '2024-04-28T05:41:02Z'},
#  {'commenter_id': 'UgzGzG-7cuVCqLkXVWt4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Trending contents these days are shit 💀and that are by youth<br>&quot;No other democratic nation has 600 million youth. The ignited mind of the youth is the most powerful resource -- on the earth, above the earth, under the earth -- and we have that&quot;<br>The ignited mind be like💀',
#   'comment_author': '@vimalpanneerselvem5603',
#   'comment_time': '2024-04-28T05:20:14Z'},
#  {'commenter_id': 'Ugx8J85jpXNbVbKxLZd4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'en yella question um neenga ketuteenga , nimathiya irukku 😌',
#   'comment_author': '@vigneshc1238',
#   'comment_time': '2024-04-28T05:11:09Z'},
#  {'commenter_id': 'UgwpH_sZWdr34V73u-t4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Super',
#   'comment_author': '@muthupandicumbum9342',
#   'comment_time': '2024-04-28T04:49:45Z'},
#  {'commenter_id': 'UgyRqcQUcaQrLNtHyaN4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': '❤❤❤',
#   'comment_author': '@naveensuresh9690',
#   'comment_time': '2024-04-28T04:38:09Z'},
#  {'commenter_id': 'UgxAxV8saIr_kuJ9D094AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Mani ya pathi unaku enna therium',
#   'comment_author': '@kombanjk',
#   'comment_time': '2024-04-28T04:09:53Z'},
#  {'commenter_id': 'UgwUCQ9F79W2EXpMTXZ4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Manikani heater ah nee',
#   'comment_author': '@kombanjk',
#   'comment_time': '2024-04-28T04:03:50Z'},
#  {'commenter_id': 'UgzBxg4RMomdMMAKNth4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': '😂',
#   'comment_author': '@shakshaycschandru1018',
#   'comment_time': '2024-04-28T02:46:30Z'},
#  {'commenter_id': 'UgwYNETBH84Hx_HVBax4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Influencer era❌mani&#39;s era ✅',
#   'comment_author': '@ushac5819',
#   'comment_time': '2024-04-27T18:59:24Z'},
#  {'commenter_id': 'UgxEmlcvpUYeBY1SvdZ4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Jio Cinema ila pakki Star sports  Tamil ,, bt Avan laa aal ila free vidu',
#   'comment_author': '@dk-od6pt',
#   'comment_time': '2024-04-27T16:15:31Z'},
#  {'commenter_id': 'UgwB0XnWXzsmnY2G9rx4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Very Beautiful 😍❤️ Akka 😍 You ❤❤',
#   'comment_author': '@SathishSathish-vq3xx',
#   'comment_time': '2024-04-27T14:51:48Z'},
#  {'commenter_id': 'UgwFzEtArE2I_O2X6ix4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Nejamave yarukum therila ethuku andha payala ponuga clg ku invite pananuga nu 😂😂',
#   'comment_author': '@WHITE_HAT_HACKER',
#   'comment_time': '2024-04-27T12:48:46Z'},
#  {'commenter_id': 'UgykBea1s5--Krc7Qyt4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Intha content worth uh! Intha college managements ku arivu varathae illa,  Need more videos like this 😂',
#   'comment_author': '@infantraj278',
#   'comment_time': '2024-04-27T11:10:12Z'},
#  {'commenter_id': 'UgyjsyJsqH2z-JZdLHB4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': '<a href="https://www.youtube.com/watch?v=T8s3QOpCX9A&amp;t=435">7:15</a> apo ponnu ipadi pannuna matum pudikuma ena 💀',
#   'comment_author': '@pravincfc291',
#   'comment_time': '2024-04-27T10:08:48Z'},
#  {'commenter_id': 'Ugxzpx1p6xIITg2zvAl4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Love from Telugu Alexwahh fans❤🎉',
#   'comment_author': '@vizagthope5044',
#   'comment_time': '2024-04-27T10:03:29Z'},
#  {'commenter_id': 'UgxmVmT1nEL7fc_f_at4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'என் மனசுல உள்ள பாரமே கொறஞ்சிருச்சு... ஆனா நீங்க தமிழை  மட்டும் சரியா உச்சரிங்க. ... 💐',
#   'comment_author': '@72petlover',
#   'comment_time': '2024-04-27T07:00:14Z'},
#  {'commenter_id': 'UgwRjb7yXe6_bZDU0Rx4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': '😂',
#   'comment_author': '@RamSaranYadav.',
#   'comment_time': '2024-04-27T05:30:03Z'},
#  {'commenter_id': 'UgwXz3f6Yr8pqEbZnfN4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Yov you inspired me... You spoked exactly what I felt.... 🎉🎉🎉🎉🎉',
#   'comment_author': '@likEdin218',
#   'comment_time': '2024-04-27T04:02:25Z'},
#  {'commenter_id': 'UgzjfCT9qIYS24REdhJ4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'At last you have guts to question this. Other influencers are still afraid to talk about these kind of people. Seriously, you went out my perspective. Huge thanks ☺️….',
#   'comment_author': '@dineshkram786',
#   'comment_time': '2024-04-27T02:51:44Z'},
#  {'commenter_id': 'UgzRnKaex-rh02fxIjJ4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Ur the real Women ❤',
#   'comment_author': '@md_sathik',
#   'comment_time': '2024-04-26T20:22:06Z'},
#  {'commenter_id': 'UgzNYJNHZsjLW3ZwznZ4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Happy to see few of you kinda youtubers exist. Thanks for speaking out what I wanted to speak. You care about people snd above all you are thinking and using your brain. Good . But its very hard to make these dumbest use their brain. Idhellam enge poi mudiyumo.. karumam karumam..',
#   'comment_author': '@munirajarathinaveltp599',
#   'comment_time': '2024-04-26T19:53:00Z'},
#  {'commenter_id': 'Ugw8jtu9n5COXDRa7ml4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': '<a href="https://www.youtube.com/watch?v=T8s3QOpCX9A&amp;t=269">4:29</a> owwww❤',
#   'comment_author': '@Shades_Of_Captured',
#   'comment_time': '2024-04-26T18:46:17Z'},
#  {'commenter_id': 'Ugwh4aXHmxq8g8xoeNd4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Ellathiyum nega cringe nu soluriga Neha pannurathu cringe ilaya ... Oru video naala Nega famous aagitiga avlotha but athukaga ivlo seen aagathu ponnu Mari nadanthukoga... Ethavathu thappa unngala  comment panna  athuku Vera thirupi bad word la pesuviga... Bad words pesarathu avlo geththa iruka ena...🙄🙄🙄',
#   'comment_author': '@sabbenasabbena5153',
#   'comment_time': '2024-04-26T16:30:24Z'},
#  {'commenter_id': 'UgzzW1NU0ewfnWTjMUB4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Yarelam athan <a href="https://www.youtube.com/watch?v=T8s3QOpCX9A&amp;t=270">4:30</a> kuh adict aninga',
#   'comment_author': '@BHARANIDHARANM23BCC007',
#   'comment_time': '2024-04-26T16:17:21Z'},
#  {'commenter_id': 'UgxoichszHZTEy8BAQh4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Vanmatha kakita da 🤣😂🤣 irundhalum ivalo vanmam iruka kudadhu ma 🤣',
#   'comment_author': '@MohanKumar-eh5xy',
#   'comment_time': '2024-04-26T15:42:26Z'},
#  {'commenter_id': 'UgyuMQ4--wDR_-7dMb14AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Tharamana seigaa maa😅 nee ultimate maa',
#   'comment_author': '@csysanjay5058',
#   'comment_time': '2024-04-26T14:46:14Z'},
#  {'commenter_id': 'UgwzRSwdbw674BiqOuB4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Naamala yarume kupdalanu poramaiya😂',
#   'comment_author': '@ramsviews5169',
#   'comment_time': '2024-04-26T13:54:37Z'},
#  {'commenter_id': 'Ugw4vcgU09z1ALUq0LJ4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Those who read her description 😂☠️',
#   'comment_author': '@Pandaloves_meenama.',
#   'comment_time': '2024-04-26T13:48:50Z'},
#  {'commenter_id': 'UgyJqokZavEihIFns4h4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Apdi avanga rendu Perum enna pudugunaga 😅😅😅 ivlo followers',
#   'comment_author': '@Shaja_04',
#   'comment_time': '2024-04-26T12:18:08Z'},
#  {'commenter_id': 'Ugx-UD81rsKU0DiwnGZ4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'I expected from the plip plip',
#   'comment_author': '@sakil0841',
#   'comment_time': '2024-04-26T08:48:29Z'},
#  {'commenter_id': 'UgxbhpcWlL9O3OVzqbR4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Yekka avana poga sollu ka anguttu 😑',
#   'comment_author': '@VSelva-rd8tn',
#   'comment_time': '2024-04-26T07:38:35Z'},
#  {'commenter_id': 'UgwLeceksKYy-XdL1Ql4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Tharamanaa speech uh🔥💥🤣',
#   'comment_author': '@55.thilageshwaran58',
#   'comment_time': '2024-04-26T05:45:18Z'},
#  {'commenter_id': 'Ugzo7eLomS9zOiZErO14AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Nalla Vela reels ah ooti vittuta, nandri ma 🙏',
#   'comment_author': '@raguldevaprakash2835',
#   'comment_time': '2024-04-26T05:05:02Z'},
#  {'commenter_id': 'UgxfIygtoM2J6dzHu8x4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Akka Nalla pesaringha 😂😂😂😂😅',
#   'comment_author': '@shaesasalambayer',
#   'comment_time': '2024-04-26T02:46:03Z'},
#  {'commenter_id': 'UgyyO2bzPZgLPz9uwmt4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Swetha (serupu vikurava )antha ponna pathi oru video podunga sis',
#   'comment_author': '@r.s.gokulshree4558',
#   'comment_time': '2024-04-26T02:15:34Z'},
#  {'commenter_id': 'UgyVQZa6VxWFnusNb4V4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'He already have wife akka😮',
#   'comment_author': '@user-uu2to9us3h',
#   'comment_time': '2024-04-25T21:42:20Z'},
#  {'commenter_id': 'UgyVzPNCrAle_H18alZ4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': '😂😂😂😂😂',
#   'comment_author': '@Arun-9629',
#   'comment_time': '2024-04-25T19:48:05Z'},
#  {'commenter_id': 'UgwlVELmbu_sbq_ca8l4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Clg culturals laam ippo invitation celebrity 📉 &lt; influencer 📈😭‼️‼️',
#   'comment_author': '@MohamedIbrahim-sc6hs',
#   'comment_time': '2024-04-25T17:44:51Z'},
#  {'commenter_id': 'UgwxgqrgTogPhscQRCt4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Akka you are a bold girl akka romba Nala the same thing going on mind Yan evalo Peru irukanga tamil nadu la life la success ana vanga Ivan enna pannita couple reel potta success aidalana ellarum oru ponnu illa na paiyana pudichi reel potu success aidalam polaye',
#   'comment_author': '@PKavin-ez7si',
#   'comment_time': '2024-04-25T17:27:07Z'},
#  {'commenter_id': 'UgxbR3EKDJ2nGuBHVV54AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Podi nayii mole',
#   'comment_author': '@DhulasiS',
#   'comment_time': '2024-04-25T15:37:45Z'},
#  {'commenter_id': 'UgyGGIq2pRyRSlI-YBp4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Ni ... Pesurathu .... Aruvi movie ya patha mariya eruku ..... ❤❤I like you .... 🎉',
#   'comment_author': '@morratusingle_cupitmkd6623',
#   'comment_time': '2024-04-25T15:11:33Z'},
#  {'commenter_id': 'Ugxy0f2BDrxAYniOmOx4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Neeyea pesi Ivana innum konjam periya aala aakiduva pola',
#   'comment_author': '@trending4k593',
#   'comment_time': '2024-04-25T15:10:12Z'},
#  {'commenter_id': 'UgylmLI_ZT6Pcq50tGh4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': 'Yarra ivanunga comedy piece ah irukanunga, choplangi mari🤣🤣🤣🤣🤣🤣🤣🤣',
#   'comment_author': '@mugilanmugil9858',
#   'comment_time': '2024-04-25T12:52:14Z'},
#  {'commenter_id': 'UgzpiRHtzE-alsIeQzp4AaABAg',
#   'video_id': 'T8s3QOpCX9A',
#   'comment_text': '<a href="https://www.youtube.com/watch?v=T8s3QOpCX9A&amp;t=462">7:42</a> akka @manichow ithu fulla fake I&#39;d nnu nenaikkiren adha vera vera ivan pin panni vachurukkan🤣',
#   'comment_author': '@gurumoorthi304',
#   'comment_time': '2024-04-25T12:48:46Z'},
#  {'commenter_id': 'UgwGtr8BFGEg9iQRHnN4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': '❤❤',
#   'comment_author': '@yeswanth6513',
#   'comment_time': '2024-04-27T15:54:17Z'},
#  {'commenter_id': 'UgxhhIYHpt3qOIZjJWF4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': 'Ada... Komala.... Hey...',
#   'comment_author': '@kirubakaranr8005',
#   'comment_time': '2024-04-26T18:27:02Z'},
#  {'commenter_id': 'UgytufVRbguImGUdaeF4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': 'Ayo pavam ne evalo video potalum ,ne just why just why banner pidichi ninalum avanga maramatanga sogam ena nanaa avangaluku English tamil theriyathu',
#   'comment_author': '@sathyanarayanan4992',
#   'comment_time': '2024-04-25T17:47:29Z'},
#  {'commenter_id': 'UgwzjX2h5hDl-BNrNk54AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': '<a href="https://www.youtube.com/watch?v=Hf1KFD98nx0&amp;t=330">5:30</a> uwwwhhh whats that , whats that brother',
#   'comment_author': '@thowfiq.k541',
#   'comment_time': '2024-04-25T00:47:35Z'},
#  {'commenter_id': 'Ugw28flMAu44lwq6GKV4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': 'Ne vera level akka ❤😂',
#   'comment_author': '@anishas6649',
#   'comment_time': '2024-04-24T14:45:38Z'},
#  {'commenter_id': 'UgyvZoQARYq6r-po3754AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': '🧏🏻👽 Bye bye...',
#   'comment_author': '@ffarjun0077',
#   'comment_time': '2024-04-23T05:08:58Z'},
#  {'commenter_id': 'UgydPjM_QcApyDj9QHZ4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': 'Take Care ❤',
#   'comment_author': '@scorpion_modelling',
#   'comment_time': '2024-04-22T20:55:09Z'},
#  {'commenter_id': 'UgyKdDTbUjdF1jBodTd4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': 'swetha...😍😍 ne apdiyae en periyama ponu thaan di .. athae yeduku madaku.. yaru di nee... cho sweet papa.. plip plip sarvs female version than. nee panu da. nalla. we support you forever',
#   'comment_author': '@manog8213',
#   'comment_time': '2024-04-22T17:39:45Z'},
#  {'commenter_id': 'UgybBL_ahboSzstJh8h4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': 'Get well soon chow👍👍',
#   'comment_author': '@chockmsd7436',
#   'comment_time': '2024-04-22T17:14:58Z'},
#  {'commenter_id': 'UgxdJnycgD6aZ7mBBrJ4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': 'Nee ipdi oru outfit pottu dance podu nanga vena ethum solala 😂😂😂😂😂',
#   'comment_author': '@kameszchemist5195',
#   'comment_time': '2024-04-22T15:37:57Z'},
#  {'commenter_id': 'UgyY-0QAJV3Fyf37dr94AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': 'Delhi metro ❌<br>Aabasa merto✅',
#   'comment_author': '@Itzzz_music_lover',
#   'comment_time': '2024-04-22T15:21:58Z'},
#  {'commenter_id': 'Ugx4b0FuAmsL7d5sPj94AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': '<a href="https://www.youtube.com/watch?v=Hf1KFD98nx0&amp;t=328">5:28</a> Ada gommala 😂😂',
#   'comment_author': '@user-sj3pj2zg4d',
#   'comment_time': '2024-04-22T11:34:35Z'},
#  {'commenter_id': 'UgxMsChbwL5Q8yMVNT14AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': 'Why don’t you try jesurathi so called Rathi amma video 🤡',
#   'comment_author': '@killerjuni8318',
#   'comment_time': '2024-04-22T08:52:48Z'},
#  {'commenter_id': 'Ugw9O9nw9K6uEA1P4j54AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': '05.23...wommmala 😅😅',
#   'comment_author': '@ashikmass9787',
#   'comment_time': '2024-04-22T05:13:47Z'},
#  {'commenter_id': 'UgxNi6noctE2SHKHcSp4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': 'Women sampavam ah 😂😂😂😂',
#   'comment_author': '@manikandananm610',
#   'comment_time': '2024-04-22T03:59:19Z'},
#  {'commenter_id': 'UgxFfJGRKem3yzpbpAF4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': 'Silirai porukuna anubavam pathi kongam slunga akkoii',
#   'comment_author': '@sumaoruchannel3839',
#   'comment_time': '2024-04-21T19:15:25Z'},
#  {'commenter_id': 'UgwqNgZi_akjpP_W1v14AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': '<a href="https://www.youtube.com/watch?v=Hf1KFD98nx0&amp;t=244">4:04</a> cold ah akka 😅',
#   'comment_author': '@blackfeathersff1992',
#   'comment_time': '2024-04-21T19:03:32Z'},
#  {'commenter_id': 'UgzIWEsKIjkiGqLzNlt4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': '@<a href="https://www.youtube.com/watch?v=Hf1KFD98nx0&amp;t=264">4:24</a> manichow got moves lol',
#   'comment_author': '@vigneswaran8358',
#   'comment_time': '2024-04-21T18:53:28Z'},
#  {'commenter_id': 'Ugx6BZfErY60_O0Io5F4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': 'Lol my 6th video really nerla pesra mari feel kandipa antha accident pathi solunga intresting ah solunga original ah soldrathinga',
#   'comment_author': '@vigneswaran8358',
#   'comment_time': '2024-04-21T18:50:16Z'},
#  {'commenter_id': 'Ugznv2Fg_EERcmkHMFp4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': 'Thats why we are called vadakans',
#   'comment_author': '@selastinprabhu1113',
#   'comment_time': '2024-04-21T17:21:00Z'},
#  {'commenter_id': 'UgxpwtVFGtDiMZeuynl4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': 'Sis how to get a jaw line like you plz😢',
#   'comment_author': '@xxx.tentasion387',
#   'comment_time': '2024-04-21T12:34:57Z'},
#  {'commenter_id': 'UgzzS9Nd6N_iFi1oejB4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': '<a href="https://www.youtube.com/watch?v=Hf1KFD98nx0&amp;t=430">7:10</a> that why!! Mah heart just whipped 💕',
#   'comment_author': '@user-iu8zv1ng1o',
#   'comment_time': '2024-04-21T09:02:49Z'},
#  {'commenter_id': 'UgxRekMX9OuTUYQgIyp4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': 'You’re so Cute ba😊be ❤',
#   'comment_author': '@rishadkhan69',
#   'comment_time': '2024-04-21T02:29:48Z'},
#  {'commenter_id': 'UgyDoGXx_8S3h4zsyJ54AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': 'Vadaky always vadaky😂😂😂😂😂😂😂',
#   'comment_author': '@sparkleno9551',
#   'comment_time': '2024-04-20T10:37:12Z'},
#  {'commenter_id': 'UgwRY6RQ4VAFJgIto_94AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': 'Siss...kovai360 channel aa pathi uum...video podungaa plzz...his reels irritate me a lot...and some silly girls are falling for him...seems more weird ☹️',
#   'comment_author': '@rithanya2920',
#   'comment_time': '2024-04-20T09:23:07Z'},
#  {'commenter_id': 'UgwsFwnoPyMPY7wtlt14AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': 'Intro video change pannuga akka',
#   'comment_author': '@vasuvamba7267',
#   'comment_time': '2024-04-19T13:36:13Z'},
#  {'commenter_id': 'UgxeoGSiYbxzVppk-yl4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': '😢😢😢😢😢',
#   'comment_author': '@visuallollipop7279',
#   'comment_time': '2024-04-19T12:28:16Z'},
#  {'commenter_id': 'Ugx1BCVbRWMEl6vOjVF4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': 'Ka disclaimer koduka mathigala soru thinura yukkk🤢',
#   'comment_author': '@ispmukesh',
#   'comment_time': '2024-04-19T11:35:32Z'},
#  {'commenter_id': 'Ugx28vocW-9S3iOarDZ4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': 'Akka I&#39;m eating and seeing this video 🤢🤮<br>Metro megi',
#   'comment_author': '@Methu...',
#   'comment_time': '2024-04-19T10:04:07Z'},
#  {'commenter_id': 'UgxU9nfthL0G_207GUh4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': '🤣',
#   'comment_author': '@shinchan822',
#   'comment_time': '2024-04-19T05:17:02Z'},
#  {'commenter_id': 'Ugx2-nInkgLChp9rGrd4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': 'If having low self esteem is a problem for Oneself, having an Inflated Self esteem is a nuicance to society',
#   'comment_author': '@gowthama2950',
#   'comment_time': '2024-04-18T14:37:40Z'},
#  {'commenter_id': 'UgyF6uzPu33ibn70Pr54AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': 'R u Malayaali',
#   'comment_author': '@rajeshpillai6304',
#   'comment_time': '2024-04-18T12:24:32Z'},
#  {'commenter_id': 'Ugx2oZYS24fhwDBCl9J4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': 'What happens to big problem  be careful will ride',
#   'comment_author': '@sarankarthik8512',
#   'comment_time': '2024-04-18T11:55:25Z'},
#  {'commenter_id': 'UgzN1tTBrCqUU1CHVkx4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': 'Why am i laughing hilariously 😂😂',
#   'comment_author': '@dvlogs_24',
#   'comment_time': '2024-04-17T15:54:29Z'},
#  {'commenter_id': 'UgwM-aJxhg2-0vTtQ0h4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': 'Nenga yentha college',
#   'comment_author': '@doli.vibexz',
#   'comment_time': '2024-04-17T06:27:53Z'},
#  {'commenter_id': 'Ugx_0SlQnKw_pvt85BZ4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': 'Ohhh pombala JK ah',
#   'comment_author': '@giridar5141',
#   'comment_time': '2024-04-16T21:15:10Z'},
#  {'commenter_id': 'UgwV3smmt1eP5EBBRLB4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': 'Just vadakan things😂😂😂',
#   'comment_author': '@KirubaNithiA',
#   'comment_time': '2024-04-16T18:14:59Z'},
#  {'commenter_id': 'Ugx_dIBuT1RNvw5Qtph4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': '<a href="https://www.youtube.com/watch?v=Hf1KFD98nx0&amp;t=328">5:28</a> i don&#39;t know what happened to people know days',
#   'comment_author': '@warren8733',
#   'comment_time': '2024-04-16T17:20:26Z'},
#  {'commenter_id': 'Ugxpfk-ZtZjuSAjBogx4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': '<a href="https://www.youtube.com/watch?v=Hf1KFD98nx0&amp;t=415">6:55</a> why ? if you get paid/popularity for views rather than content<br>its like getting marks in exam for number pages you wrote rather than content',
#   'comment_author': '@gkumartube',
#   'comment_time': '2024-04-16T17:07:38Z'},
#  {'commenter_id': 'Ugy6WzGgaBjY69hmKBd4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': '<a href="https://www.youtube.com/watch?v=Hf1KFD98nx0&amp;t=470">7:50</a> 😂',
#   'comment_author': '@kirtilinux6608',
#   'comment_time': '2024-04-16T16:47:56Z'},
#  {'commenter_id': 'UgyqbJ5DzZfHQsITuA14AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': 'The shit is happened in Delhi metro 🚇',
#   'comment_author': '@gokulgokul7307',
#   'comment_time': '2024-04-16T16:26:13Z'},
#  {'commenter_id': 'Ugx_KXxj1GYeGXpOYk54AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': '\U0001fae3',
#   'comment_author': '@azars51',
#   'comment_time': '2024-04-16T13:50:37Z'},
#  {'commenter_id': 'UgxSszw9x1uUIbQjMnR4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': 'Nxt video eappo varuthu',
#   'comment_author': '@Entertainment_videos_for_you',
#   'comment_time': '2024-04-16T13:32:54Z'},
#  {'commenter_id': 'UgyLKTZyTvGv88LhXN14AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': 'Resurrection Failed brrr... 💀',
#   'comment_author': '@maddy4295',
#   'comment_time': '2024-04-16T13:28:44Z'},
#  {'commenter_id': 'UgxeO89tJYVkREqtzmB4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': '200k subs the amount of consistent video that you make is eye-watering 🤧🤧',
#   'comment_author': '@OpTiCu',
#   'comment_time': '2024-04-16T12:31:34Z'},
#  {'commenter_id': 'Ugwt_71NX1-Ar_R0PJZ4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': 'Rip',
#   'comment_author': '@teamvilmuthish',
#   'comment_time': '2024-04-16T11:07:22Z'},
#  {'commenter_id': 'Ugyfcj7-R6gculQlG_R4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': 'Next video',
#   'comment_author': '@Kuttyma-ez8pv',
#   'comment_time': '2024-04-16T06:22:38Z'},
#  {'commenter_id': 'Ugwe62BBl0vETRNLsft4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': 'Next video yappo varum 😢',
#   'comment_author': '@HariPrasath-wl5dd',
#   'comment_time': '2024-04-16T05:20:46Z'},
#  {'commenter_id': 'Ugzuf51JjVHS8adMuZV4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': 'Rest in peace 🕊️✌🏻',
#   'comment_author': '@nothingman1016',
#   'comment_time': '2024-04-15T17:54:01Z'},
#  {'commenter_id': 'UgwbYZUqpua8b-ILHtR4AaABAg',
#   'video_id': 'Hf1KFD98nx0',
#   'comment_text': 'Ah shit!.. Gonna wait for another day😑...',
#   'comment_author': '@maddy4295',
#   'comment_time': '2024-04-15T09:44:35Z'},
#  {'commenter_id': 'UgyOk5sBsEZRm3rKNV94AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'Social media becames darker these days 😢😢',
#   'comment_author': '@akash-wf4jj',
#   'comment_time': '2024-04-27T13:41:00Z'},
#  {'commenter_id': 'UgyiaO0WDFQoCQ-cdMR4AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': '@dervinmaria1894 watch your mouth ok dont talk like shit all don&#39;t put comment that you have phone also ok all people have rights ask questions anyone have ok',
#   'comment_author': '@divheshstarz592',
#   'comment_time': '2024-04-26T18:10:06Z'},
#  {'commenter_id': 'UgyYU1d6S4SZVin-aUp4AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'Me too akka 4 months ago video JK bro.....etho oru loosu ungala romba mosama vachi video potrukka.. 😢<br><br>And akka please send the group name just to us we will alert all people and we try report them they will need go to jail because no respect girls in the group',
#   'comment_author': '@divheshstarz592',
#   'comment_time': '2024-04-26T18:08:02Z'},
#  {'commenter_id': 'UgwJpQMYWJ_g2xM--Yt4AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'Akka dont worry romba peru apadithan many people always like romba asingaama pesurathu just report them akka 😮',
#   'comment_author': '@divheshstarz592',
#   'comment_time': '2024-04-26T18:07:01Z'},
#  {'commenter_id': 'UgxglDmjLh_OyBSor454AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'akka hate comments delete panra vela iruntha sollunga akka ill do it',
#   'comment_author': '@parenchyma12',
#   'comment_time': '2024-04-25T17:00:13Z'},
#  {'commenter_id': 'Ugyf7-_Y13nWDGmQs0d4AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'Akka please watch &#39;what&#39;s going on&#39;    <br>JK Tamil video',
#   'comment_author': '@GokulAadav746',
#   'comment_time': '2024-04-25T14:06:48Z'},
#  {'commenter_id': 'UgyHDqNGbnD3Y36-MC94AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'Akka atha vedio ku like potta dhu unga lover ra atha cry panrigalla 😢',
#   'comment_author': '@dervinmaria1894',
#   'comment_time': '2024-04-25T12:31:57Z'},
#  {'commenter_id': 'UgwZY2sKxunt3s9cWYt4AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'A man is guilty until he is proven innocent<br>A woman in innocent until she is proven guilty',
#   'comment_author': '@user-ek2do9oy1w',
#   'comment_time': '2024-04-25T08:01:04Z'},
#  {'commenter_id': 'Ugxnam84Zd_LOnTCL214AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'I appreciated your work it&#39;s really happening nowadays generation are being like this! It becomes common',
#   'comment_author': '@Aravind_Sundar_',
#   'comment_time': '2024-04-25T05:57:17Z'},
#  {'commenter_id': 'Ugz-EAC7vQ1DDYdfx1J4AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'All men are not like this sister. I understand, but Do not generalize the issue. 99% of we men respect women, just ignore the 1% and move on.',
#   'comment_author': '@enchantingmusicals6488',
#   'comment_time': '2024-04-25T05:14:13Z'},
#  {'commenter_id': 'UgxyXZ5YexxGQAJOF3V4AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'It&#39;s true that most of the women affected by this kind of things....ithu internet la mattum nadakkarathillaye....Even a 50 yr old grandpa scaring me because of one man whose like my father, grandpa etc also did something horrible to me ...even i got trauma because of it now I&#39;m scared of men then i joined women&#39;s college...now only I&#39;m getting better as I&#39;m little comfort with my circumstances and because of some good men.....My great respect towards them ❤',
#   'comment_author': '@bts-ot7-army-navi',
#   'comment_time': '2024-04-25T04:44:33Z'},
#  {'commenter_id': 'UgwBzqFQRLVKJDUGV6h4AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'I PROUD MYSELF THAT I&#39;M A AJ BHAIRAV SUBSCRIBER',
#   'comment_author': '@Sarathi_Selvam.D',
#   'comment_time': '2024-04-24T18:40:31Z'},
#  {'commenter_id': 'UgwdY2OgGNb4THooVmB4AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'These things are now normalized in Instagram.<br><br>That&#39;s why I never installed that shit!!',
#   'comment_author': '@Sarathi_Selvam.D',
#   'comment_time': '2024-04-24T18:03:38Z'},
#  {'commenter_id': 'UgyQQdi1YbVcwZuQ5Cl4AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'It&#39;s a gud vdo from u sis.. aluthu onum aagathu. Actual actress ellam ithu pola vishyathuku aluthutu irunthurntha avanga field la avanga successful aagirka mudiyathu sid. Just ignore, its like people judging everyone.',
#   'comment_author': '@rajannalliah979',
#   'comment_time': '2024-04-23T20:30:09Z'},
#  {'commenter_id': 'UgzKvpGUN-1sYLbqF8Z4AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'people do this and act normal infront of other people and they meet similar peoples doing the same and the network grows on and now they aren&#39;t even scared or feel bad as they get company and support.....and once they can&#39;t control this, things will get ugly,',
#   'comment_author': '@vetrivel5134',
#   'comment_time': '2024-04-23T20:11:35Z'},
#  {'commenter_id': 'Ugy7ByV7z1K4Frzf-SJ4AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'Hi❤',
#   'comment_author': '@user-kl8ek9fc1g',
#   'comment_time': '2024-04-23T19:20:32Z'},
#  {'commenter_id': 'UgzURRaHgA_TStoF5Al4AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'Not all men&#39;s are same ...🚶',
#   'comment_author': '@madhavancrazy6687',
#   'comment_time': '2024-04-23T05:57:06Z'},
#  {'commenter_id': 'UgyUC_KVnhySBNPfGfN4AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'Let the women in our life LIVE.. Button&gt;&gt;&gt;&gt;&gt;&gt;',
#   'comment_author': '@Bxdxss',
#   'comment_time': '2024-04-23T05:45:26Z'},
#  {'commenter_id': 'UgwkYTIhi4GxkoxEhMZ4AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'Heyy.. Don&#39;t feel bad... Not every men are like this... These fuckers are obviously worthless and that&#39;s y they showcase all these kinda fatherless behaviour! <br>Don&#39;t worry darlinnn... Sheri aavum!!! ❤❤',
#   'comment_author': '@Bxdxss',
#   'comment_time': '2024-04-23T05:44:12Z'},
#  {'commenter_id': 'Ugz17NnKbTDYHPIZYi94AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'even though you make it seem like a men&#39;s problematics behaviour,there are also women out there who just speak like those men ,You can&#39;t say girls dont do the same .',
#   'comment_author': '@mikeytmg379',
#   'comment_time': '2024-04-22T16:27:51Z'},
#  {'commenter_id': 'UgwWDyYNqaYGtU01jyp4AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'Bit padam ma aduthu send panranuga ponnuga podura reels thana send panragaa',
#   'comment_author': '@hiphoplover1233',
#   'comment_time': '2024-04-22T06:43:22Z'},
#  {'commenter_id': 'UgydkhS30MPIZ1Mpnzl4AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'Normal ah alarum itha mari group la irupagaa',
#   'comment_author': '@hiphoplover1233',
#   'comment_time': '2024-04-22T06:40:55Z'},
#  {'commenter_id': 'UgwemWTJpDYrjVJ5FOJ4AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'Yaraiume nampathiga....😒',
#   'comment_author': '@manikandananm610',
#   'comment_time': '2024-04-22T02:39:33Z'},
#  {'commenter_id': 'UgxmNimwGHd7NjdvDMB4AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'Actually we appreciate you about spoke this brave and Confidencely because now a days lots of  abuse or body shame face mapping happening to girl but they get fear and feel bad to speak about this because they think it shame to us but that wrong here girl not shame that fucker doing this bad thing they want to be shame so rise voice ❤',
#   'comment_author': '@jaganath.s4612',
#   'comment_time': '2024-04-21T20:59:33Z'},
#  {'commenter_id': 'UgwYCMK5_aJj1_MHb054AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'Shame on us ( men ) 😢',
#   'comment_author': '@drstrange5997',
#   'comment_time': '2024-04-21T16:43:53Z'},
#  {'commenter_id': 'UgyGKHUNj8nHOACQQW54AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'Am.i being in another universe till yesterday am confused all these things happening i think am very privileged',
#   'comment_author': '@vigneswaran8358',
#   'comment_time': '2024-04-21T13:05:52Z'},
#  {'commenter_id': 'Ugz-SdFAvZ8UqE69OKR4AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'Stay strong...',
#   'comment_author': '@shanD7',
#   'comment_time': '2024-04-21T09:18:55Z'},
#  {'commenter_id': 'UgzvuQwVwk5mKCPfrRl4AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'there is no reason to unsubscribe you <a href="http://www.youtube.com/results?search_query=%23manichow">#manichow</a> ka A real man would never do this kind of bullshit.. we all know that. A real man will always understand your situation and will always be by your side. I&#39;m really ashamed of our kind of stupid fu*ker because of things like this.. and ya &quot;This is a man&#39;s world. But it wouldn&#39;t be nothing, nothing without a woman or a girl.&quot; ❤',
#   'comment_author': '@AronNirush',
#   'comment_time': '2024-04-20T19:29:43Z'},
#  {'commenter_id': 'UgyRI201ntkfJkoN0FB4AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'Akka can we report',
#   'comment_author': '@MjPUNIDHAN',
#   'comment_time': '2024-04-20T19:15:35Z'},
#  {'commenter_id': 'Ugzr89685H-xXv_1z_54AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'I agree with you',
#   'comment_author': '@notunithesh',
#   'comment_time': '2024-04-20T17:52:52Z'},
#  {'commenter_id': 'UgxQtsd9AChbUZZPABd4AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'In my pov this video is so important video for all women',
#   'comment_author': '@jiswanth6792',
#   'comment_time': '2024-04-20T16:17:59Z'},
#  {'commenter_id': 'UgyWsxPpWawYf_oZ2xd4AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'Unga content nalla irukku.konjam thamizhum athigama pesunga',
#   'comment_author': '@thirumalaisamy6889',
#   'comment_time': '2024-04-19T18:01:32Z'},
#  {'commenter_id': 'UgxhvFj6Gc097_0lZDd4AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'Idhula oru group of ppl, avan atleast franka or openah abusive content pesura so that avana nambalaamnu adha normalise panraanga. So idha yenna panradhu?',
#   'comment_author': '@dharshiniravi708',
#   'comment_time': '2024-04-19T12:22:31Z'},
#  {'commenter_id': 'UgySjMhj_81BUK04eax4AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': '😢',
#   'comment_author': '@user-mu7fy6op9e',
#   'comment_time': '2024-04-19T11:04:34Z'},
#  {'commenter_id': 'Ugx5QS3UFF4Rs5jq3d54AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'U gain subscribers actually for this .',
#   'comment_author': '@Paar21',
#   'comment_time': '2024-04-19T10:45:49Z'},
#  {'commenter_id': 'UgxhF5MLhUrK8qWUV7l4AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'Starting la dinosaur and thavakkala todotododoing todotodoing super',
#   'comment_author': '@RemoVibin-ve4yw',
#   'comment_time': '2024-04-19T08:36:21Z'},
#  {'commenter_id': 'Ugy762A72gsVypryFlN4AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': '<a href="https://www.youtube.com/watch?v=NEqmKa-e9vE&amp;t=520">8:40</a> the comment section- wtf the audacity of these men',
#   'comment_author': '@youngandmeowtiful',
#   'comment_time': '2024-04-19T07:54:03Z'},
#  {'commenter_id': 'Ugx1OR4mSP2vfZDjGyZ4AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'bro cycle ⛓ chain smiley podu bro',
#   'comment_author': '@balaicrishnandhasarathan9229',
#   'comment_time': '2024-04-18T20:43:21Z'},
#  {'commenter_id': 'Ugw2_kGABlqVVLgoYPp4AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'bro I 🖕 finally got why you worry you got discouraged by middle finger bro',
#   'comment_author': '@balaicrishnandhasarathan9229',
#   'comment_time': '2024-04-18T20:42:25Z'},
#  {'commenter_id': 'UgzM5Bfl9EWWV82g6vJ4AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'Bro 13 number veedu review kungumathula Potta maathiri pesureenghalae bro',
#   'comment_author': '@balaicrishnandhasarathan9229',
#   'comment_time': '2024-04-18T20:40:20Z'},
#  {'commenter_id': 'Ugx4zr19h76K9Vg2x0Z4AaABAg',
#   'video_id': 'NEqmKa-e9vE',
#   'comment_text': 'Bro your using more T in Bass 🎉nice bro',
# ...
#   'comment_author': '@DearAfzal',
#   'comment_time': '2024-04-25T14:49:33Z'},
#  {'commenter_id': 'Ugw62RFn_cSZj6PDx9F4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'eanga na ipo thanga 2-3 weeks back ketan ama konjam apdi tha irukum nu sonanga',
#   'comment_author': '@vigneswaran8358',
#   'comment_time': '2024-04-22T11:13:55Z'},
#  {'commenter_id': 'UgxXN3aZAQytJJlmV2d4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'Na matu dha ipdi irundha nenacha🤣🤣 <br>All india dha ore world, color movie, valaiyapati song samee as mee.<br><br>Enonu koda iruke, mambalama mambalam song😂',
#   'comment_author': '@deepshika0833',
#   'comment_time': '2024-04-17T15:19:19Z'},
#  {'commenter_id': 'UgzP20B7VMrKwVlpeCh4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'I was so dumb that I used to think that if I swallow apple seed or any fruit seed it will grow a tree in my stomach.. that applied to Bubblegum as well 😀 that I swallowed will somehow grow in my stomach as a Tree and I will be dead in some days... 😛 I think of it soo much that I will get similar dreams on that night while sleeping... now i am laughing alone 😀',
#   'comment_author': '@karthicksukumar90',
#   'comment_time': '2024-04-11T12:31:21Z'},
#  {'commenter_id': 'Ugyp6OG79acEAIruiEN4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'Akko same pinch <a href="https://www.youtube.com/watch?v=J1kKo_we7pA&amp;t=366">6:06</a>',
#   'comment_author': '@user-gx3be2iv1y',
#   'comment_time': '2024-04-10T15:07:58Z'},
#  {'commenter_id': 'Ugzqd0Iws1jAGa7_-Dh4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': '<a href="https://www.youtube.com/watch?v=J1kKo_we7pA&amp;t=495">8:15</a> ..... watched more than 100 times only becauseof prasad character...his dialaougs were amazing (avan varamaattan setu.....and many more)',
#   'comment_author': '@arjunsrinivas8688',
#   'comment_time': '2024-04-06T17:14:03Z'},
#  {'commenter_id': 'UgxKDl8HhyXOpaG81gJ4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': '❤',
#   'comment_author': '@vinodraj5265',
#   'comment_time': '2024-04-01T01:56:12Z'},
#  {'commenter_id': 'UgyicoRQ0jBNPaO7LKN4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'akka negha epadi kamal sr eapdi neanachighaloo apdi dhan ka nanum nenachen and same as alghiya tamil magan<br><br>🤣🤣🤣',
#   'comment_author': '@viswanathsam9983',
#   'comment_time': '2024-03-30T08:17:01Z'},
#  {'commenter_id': 'Ugw7FXFmV_7liCwCuUV4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'Laughed more reading the comments than seeing the video 😂',
#   'comment_author': '@indhulekha_with_a_h',
#   'comment_time': '2024-03-28T10:59:13Z'},
#  {'commenter_id': 'UgzMg_PvwAdFFI8oQih4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'I was also obsessed with ATM as a child, partly cos i was confused how three vijays can coexist.(particularly i was obsessed with the scene where Vijay jumps out of a building with glass getting shattered.i know it&#39;s only a dual role now, but three people coming out of the glass got me confused(i thought those were three Vijays as a child)). Plus the &quot;maduraikku pogathadi&quot; song was followed by  the protagonist getting brutally stabbed with a knife(they showed it in full detail with all the blood) in some TV&#39;s serial ad, and they showed it very frequently, which got me kinda obsessed with the whole thing since violence and gore was new to me. Was born on 2002 fr reference.',
#   'comment_author': '@vaalarivan_p',
#   'comment_time': '2024-03-25T15:12:29Z'},
#  {'commenter_id': 'UgyYzk0SSPS521NWVT94AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'Sexual awakening … 😂🤣😂',
#   'comment_author': '@Premjipremprem',
#   'comment_time': '2024-03-24T03:45:28Z'},
#  {'commenter_id': 'UgyPxAcblztU7X4Jf8t4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'Two Kamal’s … <br>Triangle rectangle 😂🤣😂',
#   'comment_author': '@Premjipremprem',
#   'comment_time': '2024-03-24T03:44:07Z'},
#  {'commenter_id': 'Ugyuak6cBIV8RjzpZ1t4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'Whole world is inside India … 🤣😂🤣',
#   'comment_author': '@Premjipremprem',
#   'comment_time': '2024-03-24T03:40:17Z'},
#  {'commenter_id': 'Ugwa8rtVQponuvzmm0Z4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'Otha kudumi busvanam … 😂',
#   'comment_author': '@Premjipremprem',
#   'comment_time': '2024-03-24T03:37:56Z'},
#  {'commenter_id': 'UgyxTGi2DpqYaOGJFH94AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'Paiyhiyakkaara kuzhandhai … 😂',
#   'comment_author': '@Premjipremprem',
#   'comment_time': '2024-03-24T03:36:49Z'},
#  {'commenter_id': 'UgwIpC56Hbpc3jH12ZZ4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'I think ur just exaggerating the &quot;pazham &quot; thing. I don&#39;t know how u define pazham but if I&#39;m crt pazham literally translates to nerd or something closer to that. In that case how could someone not look pazham in their childhood photos. Btw u were cute  in that photo. I can&#39;t find anything &quot; pazham&quot; in that pic.',
#   'comment_author': '@Thunderbear713',
#   'comment_time': '2024-03-20T14:26:08Z'},
#  {'commenter_id': 'UgxO8Osq6Bp31AX7QDV4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'Ayoo whch skl? DAV? endha branch? OMG! 😮🙌🏻💀🔥',
#   'comment_author': '@DHARANIYASURESH',
#   'comment_time': '2024-03-15T07:15:56Z'},
#  {'commenter_id': 'UgwNuOskDdS2UHm-VTp4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': '<a href="https://www.youtube.com/watch?v=J1kKo_we7pA&amp;t=370">6:10</a> 😂😂😂😂',
#   'comment_author': '@Mohan_Gopi',
#   'comment_time': '2024-03-06T20:21:17Z'},
#  {'commenter_id': 'UgwjJB04-hpX-_f3R6Z4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'India is the world , same i ised to think in 2nd standard 😂😂',
#   'comment_author': '@pcgamermaddy',
#   'comment_time': '2024-03-01T07:41:48Z'},
#  {'commenter_id': 'Ugx-oNYRPqTcY154f9R4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'Yakka chinna vayasala movies paaka mothu yaaravathu athula dead aaitangana my dumbass thinks avanga irl layum dead aaitanganu nenaippen athanala vera ethavathu movie la athe actor vanthangana ivan sethutaathaane nu keepen😂😂',
#   'comment_author': '@FriendlyShinobi1311',
#   'comment_time': '2024-02-20T16:43:39Z'},
#  {'commenter_id': 'Ugyt092uBW-gKn6aBFp4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'I thought chandramukhi nayantara was different and naanum rowdy thaan nayanthara was different i didn&#39;t even realise they were same person what i thought was.. both of their names are nayanthara😬',
#   'comment_author': '@mirushna8315',
#   'comment_time': '2024-02-04T15:25:10Z'},
#  {'commenter_id': 'UgwJwowhZglBvx40pGl4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'Naa world ey black&amp; white nu ninachitu iruntha',
#   'comment_author': '@user-dh4kq7xl9u',
#   'comment_time': '2024-02-04T14:58:17Z'},
#  {'commenter_id': 'Ugy6KPcVfiCG8vQoS6V4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'I thought after seeing mgr movies he was married to Jayalalithaa and i thought there kid was kamal',
#   'comment_author': '@bishihatedosa',
#   'comment_time': '2024-02-04T14:52:06Z'},
#  {'commenter_id': 'UgxV9RVY03D_klyQE-p4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'I was dumb enough to think that Dhanush&#39;s mother&#39;s character actually died in real life that&#39;s why she died in the movie...',
#   'comment_author': '@YoY_got_that_drip',
#   'comment_time': '2024-02-04T11:24:43Z'},
#  {'commenter_id': 'UgyJ8zDWkU38f0HMkMd4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'You said about  Kamal , naanum apditha nenachitu iruntha',
#   'comment_author': '@rohittamilan3764',
#   'comment_time': '2024-02-02T20:23:58Z'},
#  {'commenter_id': 'UgzDcX0e6ojOsi5QuVR4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'Same pinch.<br><br>Had similar thoughts in my childhood but never expressed so  like<br>1. During the black and white picture(had a thought that no one in the world has color vision)<br>2. Rainbow ending in a pot of gold.<br><br>And btw, edit of valayapathi song with cupid was really funny to watch.<br>And shriya dancing was a cringe in that song',
#   'comment_author': '@Hariharan_Elpis',
#   'comment_time': '2024-02-01T09:24:03Z'},
#  {'commenter_id': 'UgxuShAlb8ouaxA8RG54AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'In my childhood  , I was like <br>Current pona , gas stove  vum off aagirum ,<br>I asked my mom <br>How you manage to cook even though there is no current 🥲',
#   'comment_author': '@shreya2289',
#   'comment_time': '2024-01-23T11:47:06Z'},
#  {'commenter_id': 'Ugy1NJJfJ56w_sppYfN4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'Luv u ❤',
#   'comment_author': '@abishekrampranav3822',
#   'comment_time': '2024-01-20T15:19:58Z'},
#  {'commenter_id': 'UgyphZwfS_IvTtcBaTN4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'First Oru Ac Vaangi matruthu , Manichow .',
#   'comment_author': '@harishkhanna6214',
#   'comment_time': '2024-01-18T16:53:50Z'},
#  {'commenter_id': 'UgxyRXxhLwBbcMwVSK14AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': '<a href="https://www.youtube.com/watch?v=J1kKo_we7pA&amp;t=292">4:52</a> even I was thinking Thailand was in India and Singapore was in Chennai itself😂😂..so thoughtful old days😅😅😅',
#   'comment_author': '@noobdrifter6986',
#   'comment_time': '2024-01-15T16:53:19Z'},
#  {'commenter_id': 'UgxcZKyag-lG3Dp8Fzp4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'In my childhood I used to think that back in the days there were no colors in world, that&#39;s why all the old movies were black and white, I can also say that I thought of the same concept of travelling to another country involved travelling in a rocket and going to outer space and coincidentally that was during a convo over skype with my aunt who lived in Africa. I was dumb (still am) 👍',
#   'comment_author': '@kasulaaashrith',
#   'comment_time': '2024-01-14T09:47:51Z'},
#  {'commenter_id': 'UgwLC5vooJHnDb727UF4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'Naanu believe pannirkaen palaya kaalathula black and white ah tha irukumnu... To unlearn that fact was bit harder😪',
#   'comment_author': '@Boopesh-hv4no',
#   'comment_time': '2024-01-11T16:27:28Z'},
#  {'commenter_id': 'UgyJClPECzDdXt2HNnZ4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'After watching this video, i feel like a little genius 😂, thank you 😅',
#   'comment_author': '@priyankayadhav5334',
#   'comment_time': '2024-01-11T02:28:05Z'},
#  {'commenter_id': 'Ugw9mRCod_lbNX__Hsd4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'I thought all tv shows movies are happening really in other worlds and just like us watching them , they are also watching us in tv and theatres',
#   'comment_author': '@aakashak2503',
#   'comment_time': '2024-01-08T17:40:34Z'},
#  {'commenter_id': 'Ugw-QqBQ4BlJVeVnPNF4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'Naa each and every youtube video vum 1.5x la dhaa paapen <br>Apdiye indha video vum 1.5x la play aachu...<br>Then i thought why are you speaking slow, maybe i am watching in 1x...<br>After checking the speed only I realised that you were speaking too slow that even in 1.5x your speed feels like bit slower than normal<br>Or its just my brain after watching too many videos in 1.5x speed, thinking you are speaking too slow',
#   'comment_author': '@aakashak2503',
#   'comment_time': '2024-01-08T17:33:26Z'},
#  {'commenter_id': 'Ugwi3AE-syg5z-slOAh4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': '<a href="https://www.youtube.com/watch?v=J1kKo_we7pA&amp;t=410">6:50</a> same Pinch 😅',
#   'comment_author': '@srymemesfunfacts2007',
#   'comment_time': '2024-01-06T10:01:21Z'},
#  {'commenter_id': 'Ugycb8gBQ3czloQmRwd4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'i was thinking the tv programs (recorded programs ) was going live in camera dumb',
#   'comment_author': '@tharunsubbu310',
#   'comment_time': '2024-01-03T14:40:23Z'},
#  {'commenter_id': 'UgwTHnCYJi-syHl7srd4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'I once saw on TV during a cricket match, someone in the crowd had a cutout of Sachin Tendulkar&#39;s face pasted on the body of Brock LEsner, the WWE guy. So I thought Sachin is also a WWE player and eventually made up my mind that I am gonna see sachin in every sport I watch.',
#   'comment_author': '@TardigradeValorant',
#   'comment_time': '2024-01-03T08:56:23Z'},
#  {'commenter_id': 'UgxKrbHlO3y0BAuSAWF4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'oru payithiyakara kuzhandhai🤣🤣🤣',
#   'comment_author': '@ashyt7748',
#   'comment_time': '2024-01-03T06:16:53Z'},
#  {'commenter_id': 'Ugwbslb8ivUpOgYDdYF4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'why am i binge watching this gurl on new year eve 😭..... Man i&#39;m seriously got addicted to HEERRRRRRRRRR!!!!!',
#   'comment_author': '@karishadithya996',
#   'comment_time': '2024-01-01T15:11:52Z'},
#  {'commenter_id': 'Ugy8RJJ7c6PGQeCQHfZ4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'In my childhood I&#39;ve no idea about how is baby formed and how they get pregnant, as I notice that in major flim they got pregnant after a dance,so that i thought they will pregnant after the dance,so tried to learn dance 😂,thiss was dumb thinkin😅',
#   'comment_author': '@MADARA2K21',
#   'comment_time': '2024-01-01T08:28:30Z'},
#  {'commenter_id': 'UgwQGuvsViUYhe0l_l54AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'unga jawline nalla iruku',
#   'comment_author': '@righthandmanzoro',
#   'comment_time': '2023-12-30T04:04:51Z'},
#  {'commenter_id': 'UgyRpHzZdQyHQTjgaeN4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'triangle kamal , honestly relatable',
#   'comment_author': '@abdullahmohamedmusthafa2644',
#   'comment_time': '2023-12-28T21:41:47Z'},
#  {'commenter_id': 'UgxV-4TNZm4qYY0pENN4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'Same as you i thought india is the whole world and kerala is America and tamilnadu is india. 😂😅',
#   'comment_author': '@monsteryt7460',
#   'comment_time': '2023-12-26T03:51:59Z'},
#  {'commenter_id': 'UgzYWmha6xyk113JCzB4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'Konjam nera utkarunga akka 😂kalutha sachutte pesittu erukinga...valikka poguthu😅',
#   'comment_author': '@albertdurairaj1420',
#   'comment_time': '2023-12-25T03:46:04Z'},
#  {'commenter_id': 'UgyNAC9GSWzNWFPRUyZ4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'I watched all your video in a single day. Do you realise that all you say is your rant.',
#   'comment_author': '@yokeshbalaji2838',
#   'comment_time': '2023-12-24T15:22:53Z'},
#  {'commenter_id': 'Ugy7c_G42AVGBEsVZVJ4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'yeah, literally this all day i watching miss manichow vids and literally this one(manichow) made my day and ella videos aa paathi romba enjoy panta. antha tamil la pesara video and intha video will most favourite, neraya childhood memories gnyabagam aayidchi. some moments be like, &quot;na tirupati (in AP) la irupa, ennoda ulagame antha city tirupati and my relative village which is 100km far from this city. andha time only india map mattum dha therium, appo nenachadhi tirupati dha india and antha relative village dha sri lanka ni&quot;, and school la oru nalla memory kuda illa. literally that time period gave me so much trauma, cmt perusa povudhi, you&#39;re making very good content with fun(in my opinion, yaaru enna thakkadhinga) keep doin it Miss🤝',
#   'comment_author': '@ashok-rx1kk',
#   'comment_time': '2023-12-24T12:57:17Z'},
#  {'commenter_id': 'UgzcRg9-AK3jJnb_91J4AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': 'Raamakrishnan 🙃',
#   'comment_author': '@Raamakrishnan',
#   'comment_time': '2023-12-20T18:42:34Z'},
#  {'commenter_id': 'UgxTM9Y2qkvlDfWGhn94AaABAg',
#   'video_id': 'J1kKo_we7pA',
#   'comment_text': '<a href="https://www.youtube.com/watch?v=J1kKo_we7pA&amp;t=555">9:15</a>  The way she said &quot;thread&quot; with smirk. DARKER EVER! 🧵🌚',
#   'comment_author': '@ipacifist4638',
#   'comment_time': '2023-12-20T05:21:17Z'},
#  ...]

# %%
len(comment_details)
# Out:
# 1550

# %%
##getting playlist details

# %%
playlist_information=[]
request=youtube.playlists().list(
        part='snippet,contentDetails',
        channelId='UCmrsodcsfoZyFwW_f-ZtvfQ',
        maxResults=50
)
response=request.execute()
for item in response ['items']:
    playlist_data=dict(playlist_id=item['id'],
                       playlist_tittle=item['snippet']['title'],
                       channel_id=item['snippet']['channelId'],
                       Channel_name=item['snippet']['channelTitle'],
                       published_tym=item['snippet']['publishedAt'],
                       Video_count=item['contentDetails']['itemCount'])
    playlist_information.append( playlist_data)

# %%
playlist_information
# Out:
# []

# %%
def get_playlist_details(channel_id):
    next_page_token = None  # Changed variable name to follow Python conventions
    playlist_information = []

    while True:
        request = youtube.playlists().list(
            part='snippet,contentDetails',
            channelId=channel_id,
            maxResults=50,
            pageToken=next_page_token
        )
        response = request.execute()

        for item in response['items']:
            playlist_data=dict(playlist_id=item['id'],
                       playlist_tittle=item['snippet']['title'],
                       channel_id=item['snippet']['channelId'],
                       Channel_name=item['snippet']['channelTitle'],
                       published_tym=item['snippet']['publishedAt'],
                       Video_count=item['contentDetails']['itemCount'])
            playlist_information.append(playlist_data)

        next_page_token = response.get('nextPageToken')  # Corrected variable name
        if next_page_token is None:
            break

    return playlist_information

# %%
playlist_details=get_playlist_details('UCmrsodcsfoZyFwW_f-ZtvfQ')

# %%
playlist_details
# Out:
# []

# %%
#{'channel_name': 'JK ',
 'channel_id': 'UC_HZY9d5wJ-MEiuq6vhx8hg',
 'subscribers_count': '766000',
 'videos_count': '205',
 'views': '84425240',
 'channel_Description': '🤓\n',
 'playlist_id': 'UU_HZY9d5wJ-MEiuq6vhx8hg'}
# Out:
#   Cell In[34], line 2
#     'channel_id': 'UC_HZY9d5wJ-MEiuq6vhx8hg',
#     ^
# IndentationError: unexpected indent

# %%
import pandas as pd

# %%
#upload to mangodb
from pymongo import MongoClient

client = MongoClient("mongodb+srv://manobharathi:manobharathi@cluster0.1qslovj.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
db=client["youtube_data"]

# Define the collection
collection1 = db["channel_details"]

# %%
def channel_details(channel_id):
    ch_details=get_channel_info(channel_id)
    pl_details=get_playlist_details(channel_id)
    vi_ids=get_all_video_ids(channel_id)
    vi_details=get_video_information(vi_ids)
    cm_details=get_comment_details(vi_ids)
    
    collection1=db["channel_details"]
    collection1.insert_one({"channel_information":ch_details,
                            "playlist_information":pl_details,
                            "video_information":vi_details,
                            "cm_details":cm_details})
    return "upload successfull"

# %%
#jk==UC_HZY9d5wJ-MEiuq6vhx8hg
#manichow==UCmrsodcsfoZyFwW_f-ZtvfQ
#reshipedia===UCaFBtetU2RHxwnDRDsNHejA

# %%
insert=channel_details("UCmrsodcsfoZyFwW_f-ZtvfQ")

# %%
insert

# %%
#dql table creation 
import mysql.connector

# %%
ch_list=[]
db = client["youtube_data"]
collection01 = db["channel_details"]

# Iterate over documents in the collection and print the channel_informations field
for ch_data in collection01.find({}, {"_id": 0, "channel_information": 1}):
    ch_list.append(ch_data["channel_information"])
df=pd.DataFrame(ch_list)

# %%
df

# %%
import mysql.connector
import pandas as pd

def channel_table():
    try:
        mydb = mysql.connector.connect(
            host="localhost",
            user="root",
            password="Mano@3221",
            database="youtube_data",
            port="3306"
        )
        cursor = mydb.cursor()
        drop_query = '''drop table if exists channels'''
        cursor.execute(drop_query)
        mydb.commit()

        create_query = '''
        CREATE TABLE IF NOT EXISTS channels (
            channel_name VARCHAR(100),
            channel_id VARCHAR(80) PRIMARY KEY,
            subscribers_count BIGINT,
            views BIGINT,
            videos_count INT,
            channel_Description TEXT,
            playlist_id VARCHAR(80)
        )
        '''
        cursor.execute(create_query)
        mydb.commit()
        print("Channels table created successfully")

    except mysql.connector.Error as err:
        print("Error:", err)

    finally:
        if 'mydb' in locals() or 'mydb' in globals():
            mydb.close()

    ch_list = []
    db = client["youtube_data"]
    collection01 = db["channel_details"]

    # Iterate over documents in the collection and print the channel_informations field
    for ch_data in collection01.find({}, {"_id": 0, "channel_information": 1}):
        ch_list.append(ch_data["channel_information"])
    df = pd.DataFrame(ch_list)

    # Assuming you already have your DataFrame df populated

    try:
        mydb = mysql.connector.connect(
            host="localhost",
            user="root",
            password="Mano@3221",
            database="youtube_data",
            port="3306"
        )
        cursor = mydb.cursor()

        for index, row in df.iterrows():
            insert_query = '''
            INSERT INTO channels(
                channel_name,
                channel_id,
                subscribers_count,
                videos_count,
                views,
                channel_Description,
                playlist_id
            )
            VALUES (%s, %s, %s, %s, %s, %s, %s)
            '''
            values = (
                row['channel_name'],
                row['channel_id'],
                row['subscribers_count'],
                row['videos_count'],
                row['views'],
                row['channel_Description'],
                row['playlist_id']
            )

            cursor.execute(insert_query, values)
            mydb.commit()

    except mysql.connector.Error as err:
        print("values already inserted")

    finally:
        if 'mydb' in locals() or 'mydb' in globals():
            mydb.close()

channel_table()
# Out:
# Channels table created successfully

# %%
def playlist_table():
    try:
        mydb = mysql.connector.connect(
            host="localhost",
            user="root",
            password="Mano@3221",
            database="youtube_data",
            port="3306"
        )
        cursor = mydb.cursor()
        drop_query = '''drop table if exists playlists'''
        cursor.execute(drop_query)
        mydb.commit()

        create_query = '''
        CREATE TABLE IF NOT EXISTS playlists (
            playlist_id VARCHAR(100) PRIMARY KEY,
            playlist_tittle VARCHAR(80),
            channel_id VARCHAR(80),
            Channel_name VARCHAR(80),
            published_tym TIMESTAMP,
            Video_count INT)'''

        cursor.execute(create_query)
        mydb.commit()
        print("playlist table created successfully")

    except mysql.connector.Error as err:
        print("Error:", err)

    finally:
        if 'mydb' in locals() or 'mydb' in globals():
            mydb.close()



    pl_list = []
    db = client["youtube_data"]
    collection01 = db["channel_details"]

    # Iterate over documents in the collection and print the channel_informations field
    for pl_data in collection01.find({}, {"_id": 0, "playlist_information": 1}):
        for i in range(len(pl_data["playlist_information"])):
            pl_list.append(pl_data["playlist_information"][i])
    df1 = pd.DataFrame(pl_list)

    df1['published_tym'] = pd.to_datetime(df1['published_tym']).dt.strftime('%Y-%m-%d %H:%M:%S')

    try:
        mydb = mysql.connector.connect(
            host="localhost",
            user="root",
            password="Mano@3221",
            database="youtube_data",
            port="3306"
        )
        cursor = mydb.cursor()

        for index, row in df1.iterrows():
            insert_query = '''
            INSERT IGNORE INTO playlists(
                playlist_id,
                playlist_tittle,
                channel_id,
                Channel_name,
                published_tym,
                Video_count)
            VALUES (%s, %s, %s, %s, %s, %s)'''
            values = (
                row['playlist_id'],
                row['playlist_tittle'],
                row['channel_id'],
                row['Channel_name'],
                row['published_tym'],
                row['Video_count'])

            cursor.execute(insert_query, values)
            mydb.commit()

    except mysql.connector.Error as err:
        print("MySQL Error:", err)

    finally:
        if 'mydb' in locals() or 'mydb' in globals():
            mydb.close()

            
playlist_table()
# Out:
# playlist table created successfully

# %%
playlist_table

# %%
pl_list=[]
db = client["youtube_data"]
collection01 = db["channel_details"]

# Iterate over documents in the collection and print the channel_informations field
for pl_data in collection01.find({}, {"_id": 0, "playlist_information":1 }):
    for i in range(len(pl_data["playlist_information"])):
        pl_list.append(pl_data["playlist_information"][i])
df1=pd.DataFrame(pl_list)

# %%
df1

# %%
pl_data

# %% [markdown]
# channel_name=item['snippet']['channelTitle'],
#                            channel_id=item['snippet']['channelId'],
#                            video_id=item['id'],
#                            video_tittle=item['snippet']['title'],
#                            v_thumbnail=item['snippet']['thumbnails'],
#                            v_description=item['snippet']['description'],
#                            video_tags=item.get('tags'),
#                            v_date_of_publish=item['snippet']['publishedAt'],
#                            video_duration=item['contentDetails']['duration'],
#                             views_count=item['statistics']['viewCount'],
#                             comment_count=item.get('commentCount'),
#                             like_count=item['statistics']['likeCount'],
#                             fav_count=item['statistics']['favoriteCount'],
#                             video_Definition=item['contentDetails']['definition'],
#                             Caption_status=item['contentDetails']['caption']

# %%
print (df2.columns)

# %%
def video_table():
    try:
        mydb = mysql.connector.connect(
            host="localhost",
            user="root",
            password="Mano@3221",
            database="youtube_data",
            port="3306"
        )
        cursor = mydb.cursor()
        drop_query = '''DROP TABLE IF EXISTS videos'''
        cursor.execute(drop_query)
        mydb.commit()

        create_query = '''
        CREATE TABLE IF NOT EXISTS videos (
            channel_name VARCHAR(100),
            channel_id VARCHAR(80),
            video_id VARCHAR(30) PRIMARY KEY,
            video_title VARCHAR(200),
            v_thumbnail VARCHAR(200),
            v_description TEXT,
            video_tags TEXT,
            v_date_of_publish TIMESTAMP,
            video_duration VARCHAR(20),
            views_count BIGINT,
            comment_count INT,
            like_count BIGINT,
            fav_count INT,
            video_Definition VARCHAR(10),
            Caption_status VARCHAR(70)
        )'''
        cursor.execute(create_query)
        mydb.commit()
        print("videos table created successfully")

    except mysql.connector.Error as err:
        print("Error:", err)

    finally:
        if 'mydb' in locals() or 'mydb' in globals():
            mydb.close()



    vi_list=[]
    db = client["youtube_data"]
    collection01 = db["channel_details"]

    # Iterate over documents in the collection and print the channel_informations field
    for vi_data in collection01.find({}, {"_id": 0, "video_information":1 }):
        for i in range(len(vi_data["video_information"])):
            vi_list.append(vi_data["video_information"][i])
    df2 = pd.DataFrame(vi_list) 

    df2['v_date_of_publish'] = pd.to_datetime(df2['v_date_of_publish']).dt.strftime('%Y-%m-%d %H:%M:%S')

    try:
        mydb = mysql.connector.connect(
            host="localhost",
            user="root",
            password="Mano@3221",
            database="youtube_data",
            port="3306"
        )
        cursor = mydb.cursor()

        for index, row in df2.iterrows():
            insert_query = '''
            INSERT IGNORE INTO videos(
                channel_name,
                channel_id,
                video_id,
                video_title,
                v_thumbnail,
                v_description,
                video_tags,
                v_date_of_publish,
                video_duration,
                views_count,
                comment_count,
                like_count,
                fav_count,
                video_Definition,
                Caption_status
            )
            VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)'''

            values = (
                row['channel_name'],
                row['channel_id'],
                row['video_id'],
                row['video_tittle'],  
                row['v_thumbnail'],
                row['v_description'],
                row['video_tags'],
                row['v_date_of_publish'],
                str(row['video_duration']),
                row['views_count'],
                row['comment_count'],
                row['like_count'],
                row['fav_count'],
                row['video_Definition'],
                row['Caption_status']
            )

            # Ensure all values are converted to appropriate data types
            values = tuple(str(val) if isinstance(val, dict) else val for val in values)

            cursor.execute(insert_query, values)
            mydb.commit()  # Moved commit statement here

    except mysql.connector.Error as err:
        print("MySQL Error:", err)

    finally:
        if 'mydb' in locals() or 'mydb' in globals():
            mydb.close()


video_table()

# %%
# testing

# %%
def comment_table():
    try:
        mydb = mysql.connector.connect(
            host="localhost",
            user="root",
            password="Mano@3221",
            database="youtube_data",
            port="3306"
        )
        cursor = mydb.cursor()
        drop_query = '''DROP TABLE IF EXISTS comments'''
        cursor.execute(drop_query)
        mydb.commit()

        create_query = '''
        CREATE TABLE IF NOT EXISTS comments (
            commenter_id VARCHAR(100) PRIMARY KEY,
            video_id VARCHAR(80),
            comment_text TEXT,
            comment_author VARCHAR(200),
            comment_time TIMESTAMP
        )'''
        cursor.execute(create_query)
        mydb.commit()
        print("comment table created successfully")

    except mysql.connector.Error as err:
        print("Error:", err)

    finally:
        if 'mydb' in locals() or 'mydb' in globals():
            mydb.close()




    com_list=[]
    db = client["youtube_data"]
    collection01 = db["channel_details"]

    # Iterate over documents in the collection and print the channel_informations field
    for com_data in collection01.find({}, {"_id": 0, "cm_details":1 }):
        for i in range(len(com_data["cm_details"])):
            com_list.append(com_data["cm_details"][i])
    df3=pd.DataFrame(com_list)
    
    
    
    
    df3['comment_time'] = pd.to_datetime(df3['comment_time']).dt.strftime('%Y-%m-%d %H:%M:%S')

    try:
        mydb = mysql.connector.connect(
            host="localhost",
            user="root",
            password="Mano@3221",
            database="youtube_data",
            port="3306"
        )
        cursor = mydb.cursor()

        for index, row in df3.iterrows():
            insert_query = '''
            INSERT IGNORE INTO comments(
                commenter_id,
                video_id,
                comment_text,
                comment_author,
                comment_time)
            VALUES (%s, %s, %s, %s, %s)'''
            values = (
                row['commenter_id'],
                row['video_id'],
                row['comment_text'],
                row['comment_author'],
                row['comment_time'])

            cursor.execute(insert_query, values)
            mydb.commit()

    except mysql.connector.Error as err:
        print("MySQL Error:", err)

    finally:
        if 'mydb' in locals() or 'mydb' in globals():
            mydb.close()
            


comment_table()

# %%
df3

# %%
commenter_id VARCHAR(100) PRIMARY KEY,
        video_id VARCHAR(80),
        comment_text TEXT,
        comment_author VARCHAR(200),
        comment_time TIMESTAMP

# %%
def tables():
    channel_table()
    video_table()
    playlist_table()
    comment_table()
    return "tables created"

# %%
Tables=tables()

# %%
Tables

# %%
def show_channels_table():
    ch_list = []
    db = client["youtube_data"]
    collection01 = db["channel_details"]

    # Iterate over documents in the collection and print the channel_informations field
    for ch_data in collection01.find({}, {"_id": 0, "channel_information": 1}):
        ch_list.append(ch_data["channel_information"])
    df = st.dataframe(ch_list)
    
    return df

# %%
df

# %%
def show_playlists_table():
    pl_list = []
    db = client["youtube_data"]
    collection01 = db["channel_details"]

    # Iterate over documents in the collection and print the channel_informations field
    for pl_data in collection01.find({}, {"_id": 0, "playlist_information": 1}):
        for i in range(len(pl_data["playlist_information"])):
            pl_list.append(pl_data["playlist_information"][i])
    df1 = st.dataframe(pl_list)
    
    return df1

# %%
df1

# %%
def show_videos_table():
    vi_list=[]
    db = client["youtube_data"]
    collection01 = db["channel_details"]

    # Iterate over documents in the collection and print the channel_informations field
    for vi_data in collection01.find({}, {"_id": 0, "video_information":1 }):
        for i in range(len(vi_data["video_information"])):
            vi_list.append(vi_data["video_information"][i])
    df2 = st.dataframe(vi_list)
    
    return df2

# %%
df2

# %%
def show_comments_table():
    com_list=[]
    db = client["youtube_data"]
    collection01 = db["channel_details"]

    # Iterate over documents in the collection and print the channel_informations field
    for com_data in collection01.find({}, {"_id": 0, "cm_details":1 }):
        for i in range(len(com_data["cm_details"])):
            com_list.append(com_data["cm_details"][i])
    df3=st.dataframe(com_list)

# %%
df3

# %% [markdown]
# # STREAMLITE

# %%
with st.sidebar:
    st.title(":cyan[YouTube Data Harvesting and Warehousing]")
    st.header("skill takeaway")
    st.caption("python scripting")
    st.caption("data collection")
    st.caption("MongoDB")
    st.caption("API loading")
    st.caption("Data management")
    
channel_id=st.text_input("Enter the Channel ID")

if st.button("collect and store data"):
    ch_ids=[]
    db = client["youtube_data"]
    collection01 = db["channel_details"]
    for ch_data in collection01.find({}, {"_id": 0, "channel_information": 1}):
        ch_ids.append(ch_data["channel_information"]["channel_id"])
        
    if channel_id in ch_ids:
        st.success("channel details already exists")
    else:
        insert=channel_details(channel_id)
        st.success("channel details inserted")

if st.button("Import to SQL"):
    Table=Tables()
    st.success("Table imported")
    
show_table=st.radio("SELECT TABLE", ("CHANNELS", "PLAYLISTS", "VIDEOS", "COMMENTS"))

if show_table=="CHANNELS":
    show_channels_table()
    
elif show_table=="PLAYLISTS":
    show_playlists_table()
    
elif show_table=="VIDEOS":
    show_videos_table()
    
elif show_table=="COMMENTS":
    show_comments_table()

# %%
#SQl connection

# %%
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Mano@3221",
    database="youtube_data",
    port="3306")

cursor = mydb.cursor()

Question=st.selectbox("my question",("1. What are the names of all the videos and their corresponding channels",
                                     "2. Which channels have the most number of videos, and how many videos do they have",
                                     "3. What are the top 10 most viewed videos and their respective channels",
                                     "4. How many comments were made on each video, and what are their corresponding video names?",
                                     "5. Which videos have the highest number of likes, and what are their corresponding channel names?",
                                     "6. What is the total number of likes and dislikes for each video, and what are their corresponding video names?",
                                     "7. What is the total number of views for each channel, and what are their corresponding channel names?",
                                     "8. What are the names of all the channels that have published videos in the year 2022?",
                                     "9. What is the average duration of all videos in each channel, and what are their corresponding channel names?",
                                     "10. Which videos have the highest number of comments, and what are their corresponding channel names?"))

# %%
# question 1
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Mano@3221",
    database="youtube_data",
    port="3306")

cursor = mydb.cursor()

#if question=="1. What are the names of all the videos and their corresponding channels":

question01 = '''select title as Videos, channel_name as channels from videos'''
cursor.execute(question01)
mydb.commit()
t1 = cursor.fetchall()
df = pd.DataFrame(t1, columns=["video name", "channel name"])
st.write(df)

# %%
df

# %%
# question 2
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Mano@3221",
    database="youtube_data",
    port="3306")

cursor = mydb.cursor()

#if question=="2. Which channels have the most number of videos, and how many videos do they have":
question02 = '''select channel_name as Channelname, videos_count as no_videos from channels order by videos_count desc'''
cursor.execute(question02)
t2 = cursor.fetchall()
mydb.commit()
df2 = pd.DataFrame(t2, columns=["channel name", "No of videos"])
st.write(df2)

# %%
df2

# %%
# question 3
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Mano@3221",
    database="youtube_data",
    port="3306")

cursor = mydb.cursor()

#if question == "3. What are the top 10 most viewed videos and their respective channels":
question03 = '''SELECT views_count AS views, channel_name AS channelname, video_title AS videotitle 
                FROM videos WHERE views_count IS NOT NULL ORDER BY views_count DESC LIMIT 10'''
cursor.execute(question03)
#mydb.commit()
t3 = cursor.fetchall()
df3 = pd.DataFrame(t3, columns=["views", "channel name", "videotitle"])
st.write(df3)

# %%
df3

# %%
df3

# %%
# question 4 

mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Mano@3221",
    database="youtube_data",
    port="3306")

cursor = mydb.cursor()

#elif question=="4. How many comments were made on each video, and what are their corresponding video names?":
question04='''select comment_count as no_comments,video_title as videotitle from videos where comment_count is not null'''
cursor.execute(question04)
#mydb.commit()
t4=cursor.fetchall()
df4=pd.DataFrame(t4,columns=["videotitle", "no of comments"])
st.write(df4)

# %%
df4

# %%
# question 5
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Mano@3221",
    database="youtube_data",
    port="3306")

cursor = mydb.cursor()

#if question=="5. Which videos have the highest number of likes, and what are their corresponding channel names?":
question05='''select video_title as videotitle,channel_name as channelname,like_count as likecount
            from videos where like_count is not null order by like_count desc'''
cursor.execute(question05)
#mydb.commit()
t5=cursor.fetchall()
df5=pd.DataFrame(t5,columns=["videotitle","channelname","likecount"])
st.write(df5)

# %%
df5

# %%
import mysql.connector
import pandas as pd
import streamlit as st
# question 6 
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Mano@3221",
    database="youtube_data",
    port="3306")

cursor = mydb.cursor()
#if question=="6. What is the total number of likes and dislikes for each video, and what are their corresponding video names?":
question06='''select like_count as likecount,video_title as videotitle from videos'''
cursor.execute(question06)
#mydb.commit()
t6=cursor.fetchall()
df6 =pd.DataFrame(t6, columns=["likecount", "videotitle"])
st.write(df6)

# %%
df6

# %%
# question 7 

mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Mano@3221",
    database="youtube_data",
    port="3306")

cursor = mydb.cursor()

#elif question=="7. What is the total number of views for each channel, and what are their corresponding channel names?":
question07='''select channel_name as channelname ,views as totalviews from channels'''
cursor.execute(question07)
#mydb.commit()
t7=cursor.fetchall()
df7=pd.DataFrame(t7,columns=["channel name","totalviews"])
st.write(df7)

# %%
df7

# %%
import mysql.connector
import pandas as pd
import streamlit as st

mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Mano@3221",
    database="youtube_data",
    port="3306"
)

cursor = mydb.cursor()
#elif question==:"8. What are the names of all the channels that have published videos in the year 2022?"
question08 = '''SELECT 
                    video_title AS video_title, 
                    v_date_of_publish AS video_release, 
                    channel_name AS channelname 
                FROM 
                    videos
                WHERE 
                    EXTRACT(YEAR FROM v_date_of_publish) = 2022'''

cursor.execute(question08)
t8 = cursor.fetchall()
df8 = pd.DataFrame(t8, columns=["videotitle", "published_date", "channelname"])
st.write(df8)

# %%
df8

# %%
# question 9
#elif question=="9. What is the average duration of all videos in each channel, and what are their corresponding channel names?":
question09='''select channel_name as channelname,AVG(video_duration) as averageduration from videos group by channel_name'''
cursor.execute(question09)
#mydb.commit()
t9=cursor.fetchall()
df9=pd.DataFrame(t9,columns=["channelname","averageduration"])

T9=[]
for index,row in df9.iterrows():
    channel_title=row["channelname"]
    average_duration=row["averageduration"]
    average_duration_str=str(average_duration)
    T9.append(dict(channeltitle=channel_title,avgduration=average_duration_str))
df9=pd.DataFrame(T9)
st.write(df9)

# %%
df9

# %%
import mysql.connector
import pandas as pd
import streamlit as st

mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Mano@3221",
    database="youtube_data",
    port="3306"
)

cursor = mydb.cursor()
#elif question=="10. Which videos have the highest number of comments, and what are their corresponding channel names?":
question10 = '''SELECT 
                    video_title AS videotitle, 
                    channel_name AS channelname,
                    IFNULL(comment_count, 0) AS comment_count 
                FROM 
                    videos 
                WHERE 
                    comment_count IS NOT NULL 
                ORDER BY 
                    comment_count DESC'''

cursor.execute(question10)
t10 = cursor.fetchall()
df10 = pd.DataFrame(t10, columns=["video title", "channel name", "comment_count"])
st.write(df10)

# %%
df10
